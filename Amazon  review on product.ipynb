# %%
# !pip install bs4
# !pip install requests
# !pip install pandas
# Out:
# Requirement already satisfied: bs4 in c:\users\rishi patel\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\rishi patel\anaconda3\lib\site-packages (from bs4) (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\rishi patel\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (1.9.5)
# Requirement already satisfied: requests in c:\users\rishi patel\anaconda3\lib\site-packages (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\rishi patel\anaconda3\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishi patel\anaconda3\lib\site-packages (from requests) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\rishi patel\anaconda3\lib\site-packages (from requests) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\rishi patel\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: pandas in c:\users\rishi patel\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\rishi patel\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\rishi patel\anaconda3\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\rishi patel\anaconda3\lib\site-packages (from pandas) (1.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\rishi patel\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
search_query="redmi+note+10+pro"
base_url="https://www.amazon.in/s?k="
url=base_url+search_query
url
# Out:
# 'https://www.amazon.in/s?k=redmi+note+10+pro'

# %%
header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36','referer':'https://www.amazon.in/s?k=earphone'}

# %%
search_response=requests.get(url,headers=header)
search_response.status_code
# Out:
# 200

# %%
cookie={} # insert request cookies within{}
def getAmazonSearch(search_query):
    url="https://www.amazon.com/s?k="+search_query
    print(url)
    page=requests.get(url,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchasin(asin):
    url="https://www.amazon.com/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchreviews(review_link):
    url="https://www.amazon.com"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
product_names=[]
response=getAmazonSearch('redmi+note+10+pro')
soup=BeautifulSoup(response.content)
for i in soup.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'}): # the tag which is common for all the names of products
    product_names.append(i.text) #adding the product names to the list
# Out:
# https://www.amazon.com/s?k=redmi+note+10+pro

# %%
product_names
# Out:
# ['Xiaomi Redmi Note 10 Pro | 128GB 6GB RAM | Factory Unlocked (GSM ONLY | Not Compatible with Verizon/Sprint) | International Model (Onyx Gray)',
#  'Xiaomi Redmi Note 10 | 128GB 4GB RAM | GSM LTE Factory Unlocked Smartphone | International Model (Onyx Gray)',
#  'Nokia 8.3 5G | Android 10 | Unlocked Smartphone | Dual SIM | US Version | 8/128GB | 6.81-Inch Screen | 64MP Quad Camera | Polar Night',
#  'Samsung Galaxy S21 5G | Factory Unlocked Android Cell Phone | US Version 5G Smartphone | Pro-Grade Camera, 8K Video, 64MP High Res | 128GB, Phantom White (SM-G991UZWAXAA)',
#  'Xiaomi Redmi Note 10 | 128GB 4GB RAM | GSM LTE Factory Unlocked Smartphone | International Model (Pebble White)',
#  'Xiaomi Redmi Note 10 Lake Green 4Gb Ram 128Gb ROM',
#  'OnePlus Nord N10 5G, Euro 5G /Global 4G LTE, International Version (No US Warranty), Midnight Ice 128GB, 6GB - GSM Unlocked (T-Mobile, AT&T, Metro) - 64GB SD Bundle',
#  'Samsung Galaxy Note 20 Ultra 5G Factory Unlocked Android Cell Phone 128GB US Version Mobile Gaming Smartphone Long-Lasting Battery, Mystic Bronze',
#  'Xiaomi Redmi Note 9 Pro Smartphone - 6.67" DotDisplay, 6 GB + 128 GB, 64 MP AI Quad Camera, 5020mAh (typ) NFC, Bianco (Polar White)',
#  'Amosry Compatible with Xiaomi Redmi Note 10 Pro/Note 10 Pro Max Case, Drop-Resistant, Shock-Proof, Friction-Resistant,Thin and Light, for Xiaomi Redmi Note 10 Pro/Note 10 Pro Max (Green)',
#  'Xiaomi Redmi Note 9 Pro 128GB + 6GB RAM, 6.67" FHD+ DotDisplay, 64MP AI Quad Camera, Qualcomm Snapdragon 720G LTE Factory Unlocked Smartphone - International Version (Tropical Green)',
#  'Xiaomi REDMI Note 9 Dual 128GB Interstellar Grey (M2003J15SS)',
#  'Xiaomi Redmi Note 10 | 64GB 4GB RAM | Factory Unlocked (GSM ONLY | Not Compatible with Verizon/Sprint) | International Model (Lake Green)',
#  'Xiaomi Redmi Note 9 Pro Smartphone con 6.67" DotDisplay, 6 GB + 64 GB, 64 MP AI Quad Camera, 5020 mAh (type) NFC, Grigio (nterstellar Grey)',
#  'kwmobile TPU Case Compatible with Xiaomi Redmi Note 10 Pro - Case Soft Thin Slim Smooth Flexible Protective Phone Cover - Mint Matte',
#  'Samsung Galaxy A51 A515F 128GB DUOS GSM Unlocked Phone w/Quad Camera 48 MP + 12 MP + 5 MP + 5 MP (International Variant/US Compatible LTE) - Prism Crush Black',
#  'Xiaomi Redmi Note 8 Pro 128GB, 6GB RAM 6.53" LTE GSM 64MP Factory Unlocked Smartphone - Global Model (Forest Green) (Green, 128)',
#  'Red Magic 6 Pro Dual SIM 165Hz Display 5G Gaming Smartphone Factory Unlocked US Version 16 GB RAM + 256 GB 64MP Camera Android 11 Cell Phone Silver',
#  'Xiaomi Redmi Note 9T | 128GB 4GB RAM | Android 10 MIUI 12 | 5000 mAh 18W Fast Charging | Octa-core | GSM LTE Factory Unlocked Smartphone | International Model',
#  'BiubiuCase Metal Magnetic Aluminum Alloy Frame Tempered Glass Phone Case for Xiaomi Note 10/Note 10 Pro [6.47 inch] (Blue)',
#  'kwmobile Real Wood Case Compatible with Xiaomi Redmi Note 10 Pro - Wood Case Hard Wooden Cover with Soft Bumper - Dark Brown',
#  'ShinyMax Redmi Note 9 Pro Case with Roses Design,Xiaomi Note 9S/Note 9 Pro Max Case,Hybrid Triple Layer Armor Protective Cover Sturdy Anti-Scratch Shockproof Case for Women and Girls -Black/Flowers']

# %%
len(product_names)
# Out:
# 22

# %%
data_asin=[]
response=getAmazonSearch(search_query)
soup=BeautifulSoup(response.content)
for i in soup.findAll("div",{'class':"s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col sg-col-12-of-16"}):
    data_asin.append(i['data-asin'])
data_asin
# Out:
# https://www.amazon.com/s?k=redmi+note+10+pro
# ['B08Y8MDMF4',
#  'B08XZPK2HL',
#  'B08Y62HJ79',
#  'B08Y5H38YT',
#  'B0897Y6KNY',
#  'B0881TTJT6',
#  'B0881TCNX5',
#  'B07Y8Y6HVW',
#  'B08N361Y2D',
#  'B08R6H1J5R',
#  'B08BX7N9SK',
#  'B082YG1L4B',
#  'B088HJ3FCX',
#  'B07ZS1B6ZJ',
#  'B08YFJVW99',
#  'B093J49TFM']

# %%
response.status_code
# Out:
# 200

# %%
len(data_asin)
# Out:
# 16

# %%
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.com/dp/B08Y8MDMF4
# https://www.amazon.com/dp/B08XZPK2HL
# https://www.amazon.com/dp/B08Y62HJ79
# https://www.amazon.com/dp/B08Y5H38YT
# https://www.amazon.com/dp/B0897Y6KNY
# https://www.amazon.com/dp/B0881TTJT6
# https://www.amazon.com/dp/B0881TCNX5
# https://www.amazon.com/dp/B07Y8Y6HVW
# https://www.amazon.com/dp/B08N361Y2D
# https://www.amazon.com/dp/B08R6H1J5R
# https://www.amazon.com/dp/B08BX7N9SK
# https://www.amazon.com/dp/B082YG1L4B
# https://www.amazon.com/dp/B088HJ3FCX
# https://www.amazon.com/dp/B07ZS1B6ZJ
# https://www.amazon.com/dp/B08YFJVW99
# https://www.amazon.com/dp/B093J49TFM

# %%
len(link)
# Out:
# 30

# %%
reviews=[]
for j in range(len(link)):
    for k in range(1):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# https://www.amazon.com/Xiaomi-Factory-Unlocked-Compatible-International/product-reviews/B08Y8MDMF4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Factory-Unlocked-Compatible-International/product-reviews/B08Y8MDMF4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Factory-Unlocked-Smartphone-International/product-reviews/B08XZPK2HL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Factory-Unlocked-Smartphone-International/product-reviews/B08XZPK2HL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Factory-Unlocked-Smartphone-International/product-reviews/B08Y62HJ79/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Factory-Unlocked-Smartphone-International/product-reviews/B08Y62HJ79/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Redmi-Note-Green-128Gb/product-reviews/B08Y5H38YT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Redmi-Note-Green-128Gb/product-reviews/B08Y5H38YT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-DotDisplay-Qualcomm-Snapdragon-Smartphone/product-reviews/B0897Y6KNY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-DotDisplay-Qualcomm-Snapdragon-Smartphone/product-reviews/B0897Y6KNY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Redmi-Note-Pro-DotDisplay/product-reviews/B0881TTJT6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Redmi-Note-Pro-DotDisplay/product-reviews/B0881TTJT6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-DotDisplay-Qualcomm-Snapdragon-Smartphone/product-reviews/B0881TCNX5/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-DotDisplay-Qualcomm-Snapdragon-Smartphone/product-reviews/B0881TCNX5/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Redmi-Factory-Unlocked-Smartphone/product-reviews/B07Y8Y6HVW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Redmi-Factory-Unlocked-Smartphone/product-reviews/B07Y8Y6HVW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Samsung-Unlocked-Smartphone-Pro-Grade-SM-G991UZWAXAA/product-reviews/B08N361Y2D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/OnePlus-Nord-N10-5G-International/product-reviews/B08R6H1J5R/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/OnePlus-Nord-N10-5G-International/product-reviews/B08R6H1J5R/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Samsung-Electronics-Unlocked-Smartphone-Long-Lasting/product-reviews/B08BX7N9SK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Samsung-Galaxy-SM-A515F-DS-Unlocked/product-reviews/B082YG1L4B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Samsung-Galaxy-SM-A515F-DS-Unlocked/product-reviews/B082YG1L4B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-REDMI-128GB-Interstellar-M2003J15SS/product-reviews/B088HJ3FCX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-REDMI-128GB-Interstellar-M2003J15SS/product-reviews/B088HJ3FCX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Redmi-Factory-Unlocked-Smartphone/product-reviews/B07ZS1B6ZJ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Redmi-Factory-Unlocked-Smartphone/product-reviews/B07ZS1B6ZJ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Factory-Unlocked-Compatible-International/product-reviews/B08YFJVW99/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Factory-Unlocked-Compatible-International/product-reviews/B08YFJVW99/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Snapdragon-Unlocked-International-Bubblegum/product-reviews/B093J49TFM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Xiaomi-Snapdragon-Unlocked-International-Bubblegum/product-reviews/B093J49TFM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0

# %%
len(reviews)
# Out:
# 276

# %%
import json
json_file = json.dumps(reviews)
json_file
# Out:
# '["", "\\n\\n  Lo primero, he de decir que esta opini\\u00f3n es la de un comprador real, nadie me ha pagado por ella ni me ha ofrecido productos gratis. Lo digo porque le pongo 5 estrellas al Xiaomi Redmi Note 10 Pro de 6 GB de RAM y 128 GB de almacenamiento interno.Adquirido hace un par de semanas, he de decir que el tel\\u00e9fono me est\\u00e1 resultando tan satisfactorio como mi anterior Huawei P30 Lite ca\\u00eddo en acto de servicio, pero con el a\\u00f1adido de m\\u00e1s memoria RAM, un procesador m\\u00e1s potente y una pantalla mayor. No se calienta nada, el sensor de huellas lateral funciona a la perfecci\\u00f3n, el reconocimiento facial va como un tiro y el conjunto de c\\u00e1maras es m\\u00e1s que satisfactorio. Puedes hacer fotos incluso a m\\u00e1ximo de resoluci\\u00f3n (108 mpx) y luego hacer recortes pudiendo as\\u00ed suplir perfectamente la falta de un peque\\u00f1o zoom \\u00f3ptico. Los juegos se ejecutan sin problemas y el streaming va muy fluido. La carga de su bater\\u00eda de 5.000 mAh es muy r\\u00e1pida y el NFC funciona a la perfecci\\u00f3n.De momento, estoy muy satisfecho.\\n\\n", "\\n\\n  Spedizione ottima, ordinato domenica e ricevuto marted\\u00ec. Aveva un\'app di Windtre installata, non ho capito se si tratti di una versione brandizzata o globale, ad ogni modo aveva solo quella, \\u00e8 bastato rimuoverla. Telefono piuttosto grande con un\'ottima fotocamera ed una buona usabilit\\u00e0 per uso quotidiano, schermo amoled davvero stupendo. Peccato che non ci sia l\'opzione per disabilitare la ricarica rapida, bisognerebbe procurarsi un caricatore pi\\u00f9 lento a parte. Vedremo se riscontrer\\u00f2 il tanto discusso problema al sensore di prossimit\\u00e0, avendo effettuato solo poche telefonate finora non l\\u2019ho riscontrato, ma non \\u00e8 escluso che lo riscontri. Si spera che questi problemi vengano risolti al pi\\u00f9 presto con gli aggiornamenti della Miui.\\n\\n", "\\n\\n  Il telefono \\u00e8 una bomba \\u00e8 davvero bello , l\'unica pecca sta sulla batteria .. pensavo durasse di pi\\u00f9 , visto che ha 5020 di batteria .  Deluso dalla batteria\\n\\n", "\\n\\n  Overall I have this phone now for a few days and it\'s good. The battery is great it works fine but there is one major problem I think (that\'s the reason for one star) and it\'s the fact that when you\'re on a call the screen is not turned off and you can push some buttons with your face. It happened to me that it mutes my call or turn on the loudspeaker or put the call on hold to that is a major issue for me that shows this product is not mature enough. I\'m quite disappointed. Otherwise for the rest it does the job so far.\\n\\n", "\\n\\n  La cosa che mi ha dato sui nervi (e appartentemente non c\'\\u00e8 rimedio) \\u00e8 il sensore di prossimit\\u00e0 che disattiva lo schermo durante le chiamate che non funziona MAI bene, attivando cose a caso (spesso se lo si tiene con la spalla impazzisce e a volte si stacca la chiamata, si attiva il mute o inspiegabilmente si attiva il flash della fotocamera (PERCH\\u00c8?!), creandomi non pochi disagi anche con gli audio di Whatsapp. Per il resto sono abbastanza soddisfatto: batteria dura quasi due giorni pieni (utilizzando in prevalenza social e con l\'hotspot acceso almeno 3 ore al giorno), fotocamera che non fa troppo rimpiangere il top di gamma Mi10T e processore scattante ne fanno un ottimo fascia media. Lo schermo \\u00e8 molto brillante essendo un super AMOLED. Altri difetti? le fotocamere sporgono come un balcone e c\'\\u00e8 bisogno di una cover abbastanza importante per evitare che si fracassino; il gi\\u00e0 citato SENSORE DI PROSSIMITA\' e la qualit\\u00e0 delle foto al buio rispeto ad altri concorrenti di fascia media; ottima la camera grandangolare e super-grandangolare. Valido nel complesso ma delusione totale per il sensore sopra citato. Amazon una garanzia: arrivato in anticipo e ben imballato, 4 stelle.\\n\\n", "\\n\\n  Arrivato prima del previsto,complimenti al ...

# %%
with open("amazon.json", "w") as outfile:
    outfile.write(json_file)

# %%
import pandas as pd
df = pd.read_json("amazon.json")
df.to_csv("amazon_csv.csv")
df
# Out:
#                                                      0
# 0
# 1    \n\n  Lo primero, he de decir que esta opinión...
# 2    \n\n  Spedizione ottima, ordinato domenica e r...
# 3    \n\n  Il telefono è una bomba è davvero bello ...
# 4    \n\n  Overall I have this phone now for a few ...
# ..                                                 ...
# 271                                    \n\n  Bueno\n\n
# 272  \n\n  Ese es el mi 11 el de la foto. El mi 11 ...
# 273  \n\n  This phone has tons of features that mat...
# 274  \n\n  This phone works flawlessly on T-Mobile ...
# 275  \n\n  Toma fotos increíbles, tiene muy buena r...
#
# [276 rows x 1 columns]

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\rishi
# [nltk_data]     patel\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
df = df.replace('\n','', regex=True)
df.fillna("Not Available")
df.rename(columns={0: 'comment'})
# Out:
#                                                comment
# 0
# 1      Lo primero, he de decir que esta opinión es ...
# 2      Spedizione ottima, ordinato domenica e ricev...
# 3      Il telefono è una bomba è davvero bello , l'...
# 4      Overall I have this phone now for a few days...
# ..                                                 ...
# 271                                              Bueno
# 272    Ese es el mi 11 el de la foto. El mi 11 Lite...
# 273    This phone has tons of features that match t...
# 274    This phone works flawlessly on T-Mobile desp...
# 275    Toma fotos increíbles, tiene muy buena resol...
#
# [276 rows x 1 columns]

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer

# %%
words = []
for i in df[0]:
    tokenizer = RegexpTokenizer(r'\w+')
    word = tokenizer.tokenize(i)
    words.extend(word)
words
# Out:
# ['Lo',
#  'primero',
#  'he',
#  'de',
#  'decir',
#  'que',
#  'esta',
#  'opinión',
#  'es',
#  'la',
#  'de',
#  'un',
#  'comprador',
#  'real',
#  'nadie',
#  'me',
#  'ha',
#  'pagado',
#  'por',
#  'ella',
#  'ni',
#  'me',
#  'ha',
#  'ofrecido',
#  'productos',
#  'gratis',
#  'Lo',
#  'digo',
#  'porque',
#  'le',
#  'pongo',
#  '5',
#  'estrellas',
#  'al',
#  'Xiaomi',
#  'Redmi',
#  'Note',
#  '10',
#  'Pro',
#  'de',
#  '6',
#  'GB',
#  'de',
#  'RAM',
#  'y',
#  '128',
#  'GB',
#  'de',
#  'almacenamiento',
#  'interno',
#  'Adquirido',
#  'hace',
#  'un',
#  'par',
#  'de',
#  'semanas',
#  'he',
#  'de',
#  'decir',
#  'que',
#  'el',
#  'teléfono',
#  'me',
#  'está',
#  'resultando',
#  'tan',
#  'satisfactorio',
#  'como',
#  'mi',
#  'anterior',
#  'Huawei',
#  'P30',
#  'Lite',
#  'caído',
#  'en',
#  'acto',
#  'de',
#  'servicio',
#  'pero',
#  'con',
#  'el',
#  'añadido',
#  'de',
#  'más',
#  'memoria',
#  'RAM',
#  'un',
#  'procesador',
#  'más',
#  'potente',
#  'y',
#  'una',
#  'pantalla',
#  'mayor',
#  'No',
#  'se',
#  'calienta',
#  'nada',
#  'el',
#  'sensor',
#  'de',
#  'huellas',
#  'lateral',
#  'funciona',
#  'a',
#  'la',
#  'perfección',
#  'el',
#  'reconocimiento',
#  'facial',
#  'va',
#  'como',
#  'un',
#  'tiro',
#  'y',
#  'el',
#  'conjunto',
#  'de',
#  'cámaras',
#  'es',
#  'más',
#  'que',
#  'satisfactorio',
#  'Puedes',
#  'hacer',
#  'fotos',
#  'incluso',
#  'a',
#  'máximo',
#  'de',
#  'resolución',
#  '108',
#  'mpx',
#  'y',
#  'luego',
#  'hacer',
#  'recortes',
#  'pudiendo',
#  'así',
#  'suplir',
#  'perfectamente',
#  'la',
#  'falta',
#  'de',
#  'un',
#  'pequeño',
#  'zoom',
#  'óptico',
#  'Los',
#  'juegos',
#  'se',
#  'ejecutan',
#  'sin',
#  'problemas',
#  'y',
#  'el',
#  'streaming',
#  'va',
#  'muy',
#  'fluido',
#  'La',
#  'carga',
#  'de',
#  'su',
#  'batería',
#  'de',
#  '5',
#  '000',
#  'mAh',
#  'es',
#  'muy',
#  'rápida',
#  'y',
#  'el',
#  'NFC',
#  'funciona',
#  'a',
#  'la',
#  'perfección',
#  'De',
#  'momento',
#  'estoy',
#  'muy',
#  'satisfecho',
#  'Spedizione',
#  'ottima',
#  'ordinato',
#  'domenica',
#  'e',
#  'ricevuto',
#  'martedì',
#  'Aveva',
#  'un',
#  'app',
#  'di',
#  'Windtre',
#  'installata',
#  'non',
#  'ho',
#  'capito',
#  'se',
#  'si',
#  'tratti',
#  'di',
#  'una',
#  'versione',
#  'brandizzata',
#  'o',
#  'globale',
#  'ad',
#  'ogni',
#  'modo',
#  'aveva',
#  'solo',
#  'quella',
#  'è',
#  'bastato',
#  'rimuoverla',
#  'Telefono',
#  'piuttosto',
#  'grande',
#  'con',
#  'un',
#  'ottima',
#  'fotocamera',
#  'ed',
#  'una',
#  'buona',
#  'usabilità',
#  'per',
#  'uso',
#  'quotidiano',
#  'schermo',
#  'amoled',
#  'davvero',
#  'stupendo',
#  'Peccato',
#  'che',
#  'non',
#  'ci',
#  'sia',
#  'l',
#  'opzione',
#  'per',
#  'disabilitare',
#  'la',
#  'ricarica',
#  'rapida',
#  'bisognerebbe',
#  'procurarsi',
#  'un',
#  'caricatore',
#  'più',
#  'lento',
#  'a',
#  'parte',
#  'Vedremo',
#  'se',
#  'riscontrerò',
#  'il',
#  'tanto',
#  'discusso',
#  'problema',
#  'al',
#  'sensore',
#  'di',
#  'prossimità',
#  'avendo',
#  'effettuato',
#  'solo',
#  'poche',
#  'telefonate',
#  'finora',
#  'non',
#  'l',
#  'ho',
#  'riscontrato',
#  'ma',
#  'non',
#  'è',
#  'escluso',
#  'che',
#  'lo',
#  'riscontri',
#  'Si',
#  'spera',
#  'che',
#  'questi',
#  'problemi',
#  'vengano',
#  'risolti',
#  'al',
#  'più',
#  'presto',
#  'con',
#  'gli',
#  'aggiornamenti',
#  'della',
#  'Miui',
#  'Il',
#  'telefono',
#  'è',
#  'una',
#  'bomba',
#  'è',
#  'davvero',
#  'bello',
#  'l',
#  'unica',
#  'pecca',
#  'sta',
#  'sulla',
#  'batteria',
#  'pensavo',
#  'durasse',
#  'di',
#  'più',
#  'visto',
#  'che',
#  'ha',
#  '5020',
#  'di',
#  'batteria',
#  'Deluso',
#  'dalla',
#  'batteria',
#  'Overall',
#  'I',
#  'have',
#  'this',
#  'phone',
#  'now',
#  'for',
#  'a',
#  'few',
#  'days',
#  'and',
#  'it',
#  's',
#  'good',
#  'The',
#  'battery',
#  'is',
#  'great',
#  'it',
#  'works',
#  'fine',
#  'but',
#  'there',
#  'is',
#  'one',
#  'major',
#  'problem',
#  'I',
#  'think',
#  'that',
#  's',
#  'the',
#  'reason',
#  'for',
#  'one',
#  'star',
#  'and',
#  'it',
#  's',
#  'the',
#  'fact',
#  'that',
#  'when',
#  'you',
#  're',
#  'on',
#  'a',
#  'call',
#  'the',
#  'screen',
#  'is',
#  'not',
#  'turned',
#  'off',
#  'and',
#  'you',
#  'can',
#  'push',
#  'some',
#  'buttons',
#  'with',
#  'your',
#  'face',
#  'It',
#  'happened',
#  'to',
#  'me',
#  'that',
#  'it',
#  'mutes',
#  'my',
#  'call',
#  'or',
#  'turn',
#  'on',
#  'the',
#  'loudspeaker',
#  'or',
#  'put',
#  'the',
#  'call',
#  'on',
#  'hold',
#  'to',
#  'that',
#  'is',
#  'a',
#  'major',
#  'issue',
#  'for',
#  'me',
#  'that',
#  'shows',
#  'this',
#  'product',
#  'is',
#  'not',
#  'mature',
#  'enough',
#  'I',
#  'm',
#  'quite',
#  'disappointed',
#  'Otherwise',
#  'for',
#  'the',
#  'rest',
#  'it',
#  'does',
#  'the',
#  'job',
#  'so',
#  'far',
#  'La',
#  'cosa',
#  'che',
#  'mi',
#  'ha',
#  'dato',
#  'sui',
#  'nervi',
#  'e',
#  'appartentemente',
#  'non',
#  'c',
#  'è',
#  'rimedio',
#  'è',
#  'il',
#  'sensore',
#  'di',
#  'prossimità',
#  'che',
#  'disattiva',
#  'lo',
#  'schermo',
#  'durante',
#  'le',
#  'chiamate',
#  'che',
#  'non',
#  'funziona',
#  'MAI',
#  'bene',
#  'attivando',
#  'cose',
#  'a',
#  'caso',
#  'spesso',
#  'se',
#  'lo',
#  'si',
#  'tiene',
#  'con',
#  'la',
#  'spalla',
#  'impazzisce',
#  'e',
#  'a',
#  'volte',
#  'si',
#  'stacca',
#  'la',
#  'chiamata',
#  'si',
#  'attiva',
#  'il',
#  'mute',
#  'o',
#  'inspiegabilmente',
#  'si',
#  'attiva',
#  'il',
#  'flash',
#  'della',
#  'fotocamera',
#  'PERCHÈ',
#  'creandomi',
#  'non',
#  'pochi',
#  'disagi',
#  'anche',
#  'con',
#  'gli',
#  'audio',
#  'di',
#  'Whatsapp',
#  'Per',
#  'il',
#  'resto',
#  'sono',
#  'abbastanza',
#  'soddisfatto',
#  'batteria',
#  'dura',
#  'quasi',
#  'due',
#  'giorni',
#  'pieni',
#  'utilizzando',
#  'in',
#  'prevalenza',
#  'social',
#  'e',
#  'con',
#  'l',
#  'hotspot',
#  'acceso',
#  'almeno',
#  '3',
#  'ore',
#  'al',
#  'giorno',
#  'fotocamera',
#  'che',
#  'non',
#  'fa',
#  'troppo',
#  'rimpiangere',
#  'il',
#  'top',
#  'di',
#  'gamma',
#  'Mi10T',
#  'e',
#  'processore',
#  'scattante',
#  'ne',
#  'fanno',
#  'un',
#  'ottimo',
#  'fascia',
#  'media',
#  'Lo',
#  'schermo',
#  'è',
#  'molto',
#  'brillante',
#  'essendo',
#  'un',
#  'super',
#  'AMOLED',
#  'Altri',
#  'difetti',
#  'le',
#  'fotocamere',
#  'sporgono',
#  'come',
#  'un',
#  'balcone',
#  'e',
#  'c',
#  'è',
#  'bisogno',
#  'di',
#  'una',
#  'cover',
#  'abbastanza',
#  'importante',
#  'per',
#  'evitare',
#  'che',
#  'si',
#  'fracassino',
#  'il',
#  'già',
#  'citato',
#  'SENSORE',
#  'DI',
#  'PROSSIMITA',
#  'e',
#  'la',
#  'qualità',
#  'delle',
#  'foto',
#  'al',
#  'buio',
#  'rispeto',
#  'ad',
#  'altri',
#  'concorrenti',
#  'di',
#  'fascia',
#  'media',
#  'ottima',
#  'la',
#  'camera',
#  'grandangolare',
#  'e',
#  'super',
#  'grandangolare',
#  'Valido',
#  'nel',
#  'complesso',
#  'ma',
#  'delusione',
#  'totale',
#  'per',
#  'il',
#  'sensore',
#  'sopra',
#  'citato',
#  'Amazon',
#  'una',
#  'garanzia',
#  'arrivato',
#  'in',
#  'anticipo',
#  'e',
#  'ben',
#  'imballato',
#  '4',
#  'stelle',
#  'Arrivato',
#  'prima',
#  'del',
#  'previsto',
#  'complimenti',
#  'al',
#  'venditore',
#  'ed',
#  'a',
#  'Amazon',
#  'come',
#  'sempre',
#  'Dopo',
#  'qualche',
#  'giorno',
#  'di',
#  'utilizzo',
#  'posso',
#  'dire',
#  'che',
#  'è',
#  'davvero',
#  'un',
#  'ottimo',
#  'smartphone',
#  'veloce',
#  'e',
#  'fluido',
#  'anche',
#  'dopo',
#  'ore',
#  'di',
#  'utilizzo',
#  'Fotocamera',
#  'e',
#  'batteria',
#  'eccezionali',
#  'Doveva',
#  'arrivare',
#  'tra',
#  'il',
#  '27',
#  'e',
#  'il',
#  '29',
#  'aprile',
#  'invece',
#  'sorpresa',
#  'è',
#  'arrivato',
#  'il',
#  '26',
#  'Por',
#  'defecto',
#  'la',
#  'pantalla',
#  'viene',
#  'a',
#  '60',
#  'h',
#  'lo',
#  'cambié',
#  'a',
#  '120',
#  'y',
#  'duró',
#  'la',
#  'bateria',
#  'medio',
#  'diaEl',
#  'senson',
#  'de',
#  'proximidad',
#  'para',
#  'hablar',
#  'no',
#  'apaga',
#  'la',
#  'pantalla',
#  'al',
#  'acercarlo',
#  'a',
#  'la',
#  'oreja',
#  'lo',
#  'que',
#  'hace',
#  'que',
#  'cada',
#  'vez',
#  'que',
#  'hablopulse',
#  'todo',
#  'Al',
#  'hablar',
#  'con',
#  'el',
#  'altavoz',
#  'se',
#  'quejan',
#  'todos',
#  'de',
#  'que',
#  'no',
#  'se',
#  'me',
#  'escucha',
#  'tengo',
#  'que',
#  'poner',
#  'el',
#  'micrófono',
#  'a',
#  '10',
#  'cm',
#  'máximo',
#  'o',
#  'no',
#  'me',
#  'entienden',
#  'nada',
#  'La',
#  'duración',
#  'de',
#  'la',
#  'batería',
#  'dos',
#  'días',
#  'con',
#  'poco',
#  'uso',
#  'Cellulare',
#  'top',
#  'La',
#  'consegna',
#  'è',
#  'stata',
#  'iper',
#  'veloce',
#  'ci',
#  'ha',
#  'messo',
#  'soltanto',
#  'due',
#  'giorni',
#  'Imballaggio',
#  'accurato',
#  'e',
#  'sicuro',
#  'Lo',
#  'primero',
#  'he',
#  'de',
#  'decir',
#  'que',
#  'esta',
#  'opinión',
#  'es',
#  'la',
#  'de',
#  'un',
#  'comprador',
#  'real',
#  'nadie',
#  'me',
#  'ha',
#  'pagado',
#  'por',
#  'ella',
#  'ni',
#  'me',
#  'ha',
#  'ofrecido',
#  'productos',
#  'gratis',
#  'Lo',
#  'digo',
#  'porque',
#  'le',
#  'pongo',
#  '5',
#  'estrellas',
#  'al',
#  'Xiaomi',
#  'Redmi',
#  'Note',
#  '10',
#  'Pro',
#  'de',
#  '6',
#  'GB',
#  'de',
#  'RAM',
#  'y',
#  '128',
#  'GB',
#  'de',
#  'almacenamiento',
#  'interno',
#  'Adquirido',
#  'hace',
#  'un',
#  'par',
#  'de',
#  'semanas',
#  'he',
#  'de',
#  'decir',
#  'que',
#  'el',
#  'teléfono',
#  'me',
#  'está',
#  'resultando',
#  'tan',
#  'satisfactorio',
#  'como',
#  'mi',
#  'anterior',
#  'Huawei',
#  'P30',
#  'Lite',
#  'caído',
#  'en',
#  'acto',
#  'de',
#  'servicio',
#  'pero',
#  'con',
#  'el',
#  'añadido',
#  'de',
#  'más',
#  'memoria',
#  'RAM',
#  'un',
#  'procesador',
#  'más',
#  'potente',
#  'y',
#  'una',
#  'pantalla',
#  'mayor',
#  'No',
#  'se',
#  'calienta',
#  'nada',
#  'el',
#  'sensor',
#  'de',
#  'huellas',
#  'lateral',
#  'funciona',
#  'a',
#  'la',
#  'perfección',
#  'el',
#  'reconocimiento',
#  'facial',
#  'va',
#  'como',
#  'un',
#  'tiro',
#  'y',
#  'el',
#  'conjunto',
#  'de',
#  'cámaras',
#  'es',
#  'más',
#  'que',
#  'satisfactorio',
#  'Puedes',
#  'hacer',
#  'fotos',
#  'incluso',
#  'a',
#  'máximo',
#  'de',
#  'resolución',
#  '108',
#  'mpx',
#  'y',
#  'luego',
#  'hacer',
#  'recortes',
#  'pudiendo',
#  'así',
#  'suplir',
#  'perfectamente',
#  'la',
#  'falta',
#  'de',
#  'un',
#  'pequeño',
#  'zoom',
#  'óptico',
#  'Los',
#  'juegos',
#  'se',
#  'ejecutan',
#  'sin',
#  'problemas',
#  'y',
#  'el',
#  'streaming',
#  'va',
#  'muy',
#  'fluido',
#  'La',
#  'carga',
#  'de',
#  'su',
#  'batería',
#  'de',
#  '5',
#  '000',
#  'mAh',
#  'es',
#  'muy',
#  'rápida',
#  'y',
#  'el',
#  'NFC',
#  'funciona',
#  'a',
#  'la',
#  'perfección',
#  'De',
#  'momento',
#  'estoy',
#  'muy',
#  'satisfecho',
#  'Spedizione',
#  'ottima',
#  'ordinato',
#  'domenica',
#  'e',
#  'ricevuto',
#  'martedì',
#  'Aveva',
#  'un',
#  'app',
#  'di',
#  'Windtre',
#  'installata',
#  'non',
#  'ho',
#  'capito',
#  'se',
#  'si',
#  'tratti',
#  'di',
#  'una',
#  'versione',
#  'brandizzata',
#  'o',
#  'globale',
#  'ad',
#  'ogni',
#  'modo',
#  ...]

# %%
len(words)
# Out:
# 31917

# %%
from nltk import FreqDist
frequency = FreqDist(words)
frequency
# Out:
# FreqDist({'the': 1192, 'I': 901, 'and': 741, 'a': 694, 'it': 647, 'phone': 628, 'is': 618, 'to': 618, 'with': 371, 'for': 322, ...})

# %%
unique_words = []
for i in frequency:
    unique_words.append(i)
len(unique_words)
# Out:
# 3420

# %%
from nltk import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
for i in unique_words:
    print("{} : {}".format(i, lemmatizer.lemmatize(i)))
# Out:
# Lo : Lo
# primero : primero
# he : he
# de : de
# decir : decir
# que : que
# esta : esta
# opinión : opinión
# es : e
# la : la
# un : un
# comprador : comprador
# real : real
# nadie : nadie
# me : me
# ha : ha
# pagado : pagado
# por : por
# ella : ella
# ni : ni
# ofrecido : ofrecido
# productos : productos
# gratis : gratis
# digo : digo
# porque : porque
# le : le
# pongo : pongo
# 5 : 5
# estrellas : estrellas
# al : al
# Xiaomi : Xiaomi
# Redmi : Redmi
# Note : Note
# 10 : 10
# Pro : Pro
# 6 : 6
# GB : GB
# RAM : RAM
# y : y
# 128 : 128
# almacenamiento : almacenamiento
# interno : interno
# Adquirido : Adquirido
# hace : hace
# par : par
# semanas : semanas
# el : el
# teléfono : teléfono
# está : está
# resultando : resultando
# tan : tan
# satisfactorio : satisfactorio
# como : como
# mi : mi
# anterior : anterior
# Huawei : Huawei
# P30 : P30
# Lite : Lite
# caído : caído
# en : en
# acto : acto
# servicio : servicio
# pero : pero
# con : con
# añadido : añadido
# más : más
# memoria : memoria
# procesador : procesador
# potente : potente
# una : una
# pantalla : pantalla
# mayor : mayor
# No : No
# se : se
# calienta : calienta
# nada : nada
# sensor : sensor
# huellas : huellas
# lateral : lateral
# funciona : funciona
# a : a
# perfección : perfección
# reconocimiento : reconocimiento
# facial : facial
# va : va
# tiro : tiro
# conjunto : conjunto
# cámaras : cámaras
# Puedes : Puedes
# hacer : hacer
# fotos : fotos
# incluso : incluso
# máximo : máximo
# resolución : resolución
# 108 : 108
# mpx : mpx
# luego : luego
# recortes : recortes
# pudiendo : pudiendo
# así : así
# suplir : suplir
# perfectamente : perfectamente
# falta : falta
# pequeño : pequeño
# zoom : zoom
# óptico : óptico
# Los : Los
# juegos : juegos
# ejecutan : ejecutan
# sin : sin
# problemas : problemas
# streaming : streaming
# muy : muy
# fluido : fluido
# La : La
# carga : carga
# su : su
# batería : batería
# 000 : 000
# mAh : mAh
# rápida : rápida
# NFC : NFC
# De : De
# momento : momento
# estoy : estoy
# satisfecho : satisfecho
# Spedizione : Spedizione
# ottima : ottima
# ordinato : ordinato
# domenica : domenica
# e : e
# ricevuto : ricevuto
# martedì : martedì
# Aveva : Aveva
# app : app
# di : di
# Windtre : Windtre
# installata : installata
# non : non
# ho : ho
# capito : capito
# si : si
# tratti : tratti
# versione : versione
# brandizzata : brandizzata
# o : o
# globale : globale
# ad : ad
# ogni : ogni
# modo : modo
# aveva : aveva
# solo : solo
# quella : quella
# è : è
# bastato : bastato
# rimuoverla : rimuoverla
# Telefono : Telefono
# piuttosto : piuttosto
# grande : grande
# fotocamera : fotocamera
# ed : ed
# buona : buona
# usabilità : usabilità
# per : per
# uso : uso
# quotidiano : quotidiano
# schermo : schermo
# amoled : amoled
# davvero : davvero
# stupendo : stupendo
# Peccato : Peccato
# che : che
# ci : ci
# sia : sia
# l : l
# opzione : opzione
# disabilitare : disabilitare
# ricarica : ricarica
# rapida : rapida
# bisognerebbe : bisognerebbe
# procurarsi : procurarsi
# caricatore : caricatore
# più : più
# lento : lento
# parte : parte
# Vedremo : Vedremo
# riscontrerò : riscontrerò
# il : il
# tanto : tanto
# discusso : discusso
# problema : problema
# sensore : sensore
# prossimità : prossimità
# avendo : avendo
# effettuato : effettuato
# poche : poche
# telefonate : telefonate
# finora : finora
# riscontrato : riscontrato
# ma : ma
# escluso : escluso
# lo : lo
# riscontri : riscontri
# Si : Si
# spera : spera
# questi : questi
# problemi : problemi
# vengano : vengano
# risolti : risolti
# presto : presto
# gli : gli
# aggiornamenti : aggiornamenti
# della : della
# Miui : Miui
# Il : Il
# telefono : telefono
# bomba : bomba
# bello : bello
# unica : unica
# pecca : pecca
# sta : sta
# sulla : sulla
# batteria : batteria
# pensavo : pensavo
# durasse : durasse
# visto : visto
# 5020 : 5020
# Deluso : Deluso
# dalla : dalla
# Overall : Overall
# I : I
# have : have
# this : this
# phone : phone
# now : now
# for : for
# few : few
# days : day
# and : and
# it : it
# s : s
# good : good
# The : The
# battery : battery
# is : is
# great : great
# works : work
# fine : fine
# but : but
# there : there
# one : one
# major : major
# problem : problem
# think : think
# that : that
# the : the
# reason : reason
# star : star
# fact : fact
# when : when
# you : you
# re : re
# on : on
# call : call
# screen : screen
# not : not
# turned : turned
# off : off
# can : can
# push : push
# some : some
# buttons : button
# with : with
# your : your
# face : face
# It : It
# happened : happened
# to : to
# mutes : mute
# my : my
# or : or
# turn : turn
# loudspeaker : loudspeaker
# put : put
# hold : hold
# issue : issue
# shows : show
# product : product
# mature : mature
# enough : enough
# m : m
# quite : quite
# disappointed : disappointed
# Otherwise : Otherwise
# rest : rest
# does : doe
# job : job
# so : so
# far : far
# cosa : cosa
# dato : dato
# sui : sui
# nervi : nervi
# appartentemente : appartentemente
# c : c
# rimedio : rimedio
# disattiva : disattiva
# durante : durante
# chiamate : chiamate
# funziona : funziona
# MAI : MAI
# bene : bene
# attivando : attivando
# cose : cose
# caso : caso
# spesso : spesso
# tiene : tiene
# spalla : spalla
# impazzisce : impazzisce
# volte : volta
# stacca : stacca
# chiamata : chiamata
# attiva : attiva
# mute : mute
# inspiegabilmente : inspiegabilmente
# flash : flash
# PERCHÈ : PERCHÈ
# creandomi : creandomi
# pochi : pochi
# disagi : disagi
# anche : anche
# audio : audio
# Whatsapp : Whatsapp
# Per : Per
# resto : resto
# sono : sono
# abbastanza : abbastanza
# soddisfatto : soddisfatto
# dura : dura
# quasi : quasi
# due : due
# giorni : giorni
# pieni : pieni
# utilizzando : utilizzando
# in : in
# prevalenza : prevalenza
# social : social
# hotspot : hotspot
# acceso : acceso
# almeno : almeno
# 3 : 3
# ore : ore
# giorno : giorno
# fa : fa
# troppo : troppo
# rimpiangere : rimpiangere
# top : top
# gamma : gamma
# Mi10T : Mi10T
# processore : processore
# scattante : scattante
# ne : ne
# fanno : fanno
# ottimo : ottimo
# fascia : fascia
# media : medium
# molto : molto
# brillante : brillante
# essendo : essendo
# super : super
# AMOLED : AMOLED
# Altri : Altri
# difetti : difetti
# fotocamere : fotocamere
# sporgono : sporgono
# come : come
# balcone : balcone
# bisogno : bisogno
# cover : cover
# importante : importante
# evitare : evitare
# fracassino : fracassino
# già : già
# citato : citato
# SENSORE : SENSORE
# DI : DI
# PROSSIMITA : PROSSIMITA
# qualità : qualità
# delle : delle
# foto : foto
# buio : buio
# rispeto : rispeto
# altri : altri
# concorrenti : concorrenti
# camera : camera
# grandangolare : grandangolare
# Valido : Valido
# nel : nel
# complesso : complesso
# delusione : delusione
# totale : totale
# sopra : sopra
# Amazon : Amazon
# garanzia : garanzia
# arrivato : arrivato
# anticipo : anticipo
# ben : ben
# imballato : imballato
# 4 : 4
# stelle : stelle
# Arrivato : Arrivato
# prima : prima
# del : del
# previsto : previsto
# complimenti : complimenti
# venditore : venditore
# sempre : sempre
# Dopo : Dopo
# qualche : qualche
# utilizzo : utilizzo
# posso : posso
# dire : dire
# smartphone : smartphone
# veloce : veloce
# dopo : dopo
# Fotocamera : Fotocamera
# eccezionali : eccezionali
# Doveva : Doveva
# arrivare : arrivare
# tra : tra
# 27 : 27
# 29 : 29
# aprile : aprile
# invece : invece
# sorpresa : sorpresa
# 26 : 26
# Por : Por
# defecto : defecto
# viene : viene
# 60 : 60
# h : h
# cambié : cambié
# 120 : 120
# duró : duró
# bateria : bateria
# medio : medio
# diaEl : diaEl
# senson : senson
# proximidad : proximidad
# para : para
# hablar : hablar
# no : no
# apaga : apaga
# acercarlo : acercarlo
# oreja : oreja
# cada : cada
# vez : vez
# hablopulse : hablopulse
# todo : todo
# Al : Al
# altavoz : altavoz
# quejan : quejan
# todos : todos
# escucha : escucha
# tengo : tengo
# poner : poner
# micrófono : micrófono
# cm : cm
# entienden : entienden
# duración : duración
# dos : do
# días : días
# poco : poco
# Cellulare : Cellulare
# consegna : consegna
# stata : stata
# iper : iper
# messo : messo
# soltanto : soltanto
# Imballaggio : Imballaggio
# accurato : accurato
# sicuro : sicuro
# Works : Works
# metro : metro
# pay : pay
# fee : fee
# Not : Not
# negative : negative
# just : just
# Pros : Pros
# looks : look
# display : display
# comes : come
# substantial : substantial
# case : case
# life : life
# Cons : Cons
# UI : UI
# buggy : buggy
# graphics : graphic
# are : are
# become : become
# very : very
# annoying : annoying
# all : all
# sporadic : sporadic
# glitches : glitch
# system : system
# On : On
# bright : bright
# side : side
# something : something
# could : could
# be : be
# completely : completely
# fixed : fixed
# either : either
# future : future
# updates : update
# installing : installing
# custom : custom
# ROM : ROM
# Although : Although
# may : may
# more : more
# difficult : difficult
# install : install
# device : device
# its : it
# recent : recent
# launch : launch
# Develop : Develop
# actually : actually
# need : need
# build : build
# viable : viable
# recovery : recovery
# software : software
# ROMs : ROMs
# compatible : compatible
# particular : particular
# So : So
# fortunately : fortunately
# as : a
# time : time
# goes : go
# likeliness : likeliness
# of : of
# becoming : becoming
# really : really
# awsome : awsome
# budget : budget
# solution : solution
# will : will
# greatly : greatly
# increase : increase
# received : received
# yesterday : yesterday
# mobile : mobile
# charges : charge
# quickly : quickly
# has : ha
# power : power
# day : day
# am : am
# satisfied : satisfied
# If : If
# live : live
# US : US
# avoid : avoid
# at : at
# costs : cost
# radios : radio
# functional : functional
# You : You
# drop : drop
# every : every
# get : get
# miss : miss
# 80 : 80
# them : them
# Those : Those
# do : do
# talk : talk
# hear : hear
# what : what
# sounds : sound
# like : like
# cafeteria : cafeteria
# return : return
# wait : wait
# find : find
# else : else
# Just : Just
# huge : huge
# pain : pain
# ve : ve
# been : been
# using : using
# daily : daily
# drive : drive
# experience : experience
# A : A
# awesome : awesome
# pleasant : pleasant
# eyes : eye
# dark : dark
# mode : mode
# built : built
# Amazing : Amazing
# never : never
# having : having
# worrying : worrying
# about : about
# charging : charging
# often : often
# which : which
# nice : nice
# As : As
# well : well
# being : being
# use : use
# almost : almost
# any : any
# provider : provider
# MetroPCS : MetroPCS
# T : T
# Mobile : Mobile
# Really : Really
# hoping : hoping
# brings : brings
# phones : phone
# over : over
# west : west
# This : This
# bang : bang
# buck : buck
# highly : highly
# needed : needed
# here : here
# Going : Going
# sticking : sticking
# brand : brand
# while : while
# Good : Good
# price : price
# AT : AT
# LTE : LTE
# connection : connection
# problems : problem
# Angeles : Angeles
# area : area
# Corresponde : Corresponde
# las : la
# expectativas : expectativas
# much : much
# cell : cell
# read : read
# emails : email
# take : take
# pictures : picture
# record : record
# videos : video
# vida : vida
# buena : buena
# Pero : Pero
# celular : celular
# Se : Se
# arruino : arruino
# menos : menos
# 2 : 2
# meses : me
# work : work
# Me : Me
# encanto : encanto
# tuve : tuve
# regresar : regresar
# venia : venia
# deabloqueado : deabloqueado
# El : El
# mejor : mejor
# tenido : tenido
# Excelente : Excelente
# relación : relación
# precio : precio
# calidad : calidad
# cuenta : cuenta
# varias : varias
# funciones : funciones
# gama : gama
# bajo : bajo
# costo : costo
# comparado : comparado
# otros : otros
# mercado : mercado
# Lamentablemente : Lamentablemente
# operadores : operadores
# Estados : Estados
# Unidos : Unidos
# tube : tube
# producto : producto
# puedo : puedo
# usarlo : usarlo
# bandas : bandas
# trae : trae
# europa : europa
# América : América
# usamos : usamos
# europeas : europeas
# posiblemente : posiblemente
# puede : puede
# funcione : funcione
# 2G : 2G
# sería : sería
# agradable : agradable
# hay : hay
# operadoras : operadoras
# got : got
# lemon : lemon
# today : today
# Phone : Phone
# reboot : reboot
# two : two
# three : three
# minutes : minute
# touch : touch
# frequently : frequently
# freeze : freeze
# give : give
# replacement : replacement
# company : company
# thank : thank
# Will : Will
# update : update
# i : i
# receive : receive
# único : único
# gusta : gusta
# siento : siento
# cuando : cuando
# respaldo : respaldo
# WhatsApp : WhatsApp
# tarda : tarda
# muchoPor : muchoPor
# demás : demás
# bien : bien
# Esta : Esta
# correctamente : correctamente
# Buen : Buen
# equipo : equipo
# beneficio : beneficio
# thing : thing
# absolute : absolute
# favorite : favorite
# bought : bought
# because : because
# was : wa
# long : long
# overdue : overdue
# an : an
# upgrade : upgrade
# My : My
# last : last
# already : already
# kind : kind
# old : old
# years : year
# ago : ago
# fantastic : fantastic
# little : little
# everything : everything
# high : high
# end : end
# quarter : quarter
# Between : Between
# 4K : 4K
# 64Mp : 64Mp
# t : t
# complain : complain
# had : had
# warn : warn
# anything : anything
# slowmo : slowmo
# feature : feature
# Yes : Yes
# only : only
# slows : slows
# down : down
# second : second
# video : video
# bad : bad
# math : math
# seconds : second
# phenomenal : phenomenal
# though : though
# incredibly : incredibly
# responsive : responsive
# gorgeous : gorgeous
# back : back
# pretty : pretty
# decided : decided
# clear : clear
# hide : hide
# afraid : afraid
# going : going
# break : break
# know : know
# absolutely : absolutely
# worth : worth
# than : than
# they : they
# asking : asking
# did : did
# 9 : 9
# those : those
# thoughts : thought
# changed : changed
# Day : Day
# 1 : 1
# arrived : arrived
# lovely : lovely
# piece : piece
# equipment : equipment
# ordered : ordered
# green : green
# size : size
# weight : weight
# looked : looked
# narrower : narrower
# shorter : shorter
# galaxy : galaxy
# note : note
# fit : fit
# into : into
# redmi : redmi
# PROSScreen : PROSScreen
# Side : Side
# fingerprint : fingerprint
# detection : detection
# button : button
# novel : novel
# games : game
# play : play
# were : were
# connected : connected
# wifi : wifi
# overall : overall
# look : look
# pleasing : pleasing
# CONSI : CONSI
# couldn : couldn
# incoming : incoming
# calls : call
# callers : caller
# didn : didn
# leave : leave
# voice : voice
# message : message
# text : text
# would : would
# known : known
# called : called
# Call : Call
# quality : quality
# poor : poor
# people : people
# barely : barely
# speaker : speaker
# subpar : subpar
# opinion : opinion
# loud : loud
# also : also
# definitely : definitely
# equalizer : equalizer
# literally : literally
# took : took
# 45 : 45
# line : line
# ring : ring
# after : after
# number : number
# dialed : dialed
# EVERY : EVERY
# made : made
# Honestly : Honestly
# if : if
# basic : basic
# function : function
# making : making
# receiving : receiving
# d : d
# consider : consider
# keeping : keeping
# don : don
# lot : lot
# calling : calling
# expect : expect
# unlocked : unlocked
# GSM : GSM
# expected : expected
# properly : properly
# carrier : carrier
# deal : deal
# breaker : breaker
# love : love
# shouldn : shouldn
# 250 : 250
# sooo : sooo
# even : even
# gets : get
# praise : praise
# course : course
# full : full
# 64mp : 64mp
# stacks : stack
# images : image
# cleanest : cleanest
# ever : ever
# seen : seen
# under : under
# 500 : 500
# amazing : amazing
# out : out
# box : box
# lasted : lasted
# half : half
# reader : reader
# picky : picky
# means : mean
# gonna : gonna
# let : let
# error : error
# around : around
# especially : especially
# gaming : gaming
# whatever : whatever
# want : want
# latency : latency
# llego : llego
# novedad : novedad
# aunque : aunque
# fue : fue
# importado : importado
# Ecuador : Ecuador
# ningun : ningun
# daño : daño
# empaquetado : empaquetado
# tuvo : tuvo
# ningún : ningún
# owning : owning
# paying : paying
# Samsung : Samsung
# A70 : A70
# liked : liked
# finger : finger
# print : print
# scanner : scanner
# crap : crap
# tried : tried
# through : through
# help : help
# told : told
# since : since
# universal : universal
# wasn : wasn
# covered : covered
# Then : Then
# broke : broke
# YAY : YAY
# new : new
# reading : reading
# up : up
# reviews : review
# comparing : comparing
# specs : spec
# recommend : recommend
# 100 : 100
# speak : speak
# crystal : crystal
# runs : run
# Apps : Apps
# perfectly : perfectly
# Buy : Buy
# hardware : hardware
# Snapdragon : Snapdragon
# 720G : 720G
# 128GB : 128GB
# 6GB : 6GB
# 2400 : 2400
# x : x
# 1080 : 1080
# FHD : FHD
# 64MP : 64MP
# etc : etc
# Major : Major
# dump : dump
# equip : equip
# iPhone : iPhone
# knock : knock
# Launcher : Launcher
# totally : totally
# lacks : lack
# affinity : affinity
# Android : Android
# Bloatware : Bloatware
# make : make
# worse : worse
# cannot : cannot
# without : without
# bloatware : bloatware
# their : their
# own : own
# launcher : launcher
# stock : stock
# functionalities : functionality
# ridiculous : ridiculous
# replace : replace
# inferior : inferior
# home : home
# brew : brew
# flexware : flexware
# wish : wish
# understand : understand
# buyers : buyer
# Es : Es
# excelente : excelente
# inversion : inversion
# tienes : tienes
# 8 : 8
# pro : pro
# gusto : gusto
# camara : camara
# sobresale : sobresale
# carcaza : carcaza
# ya : ya
# nota : nota
# Funciona : Funciona
# rapido : rapido
# toma : toma
# buenas : buenas
# mucho : mucho
# gigante : gigante
# Tardare : Tardare
# buen : buen
# tiempo : tiempo
# este : este
# LOVE : LOVE
# unfortunately : unfortunately
# issues : issue
# breakers : breaker
# returning : returning
# AMAZING : AMAZING
# Seriously : Seriously
# past : past
# keep : keep
# alone : alone
# crisp : crisp
# color : color
# notch : notch
# charge : charge
# moderate : moderate
# phantom : phantom
# touches : touch
# sometimes : sometimes
# haven : haven
# touched : touched
# hover : hover
# thinks : think
# tapped : tapped
# supported : supported
# by : by
# most : most
# carriers : carrier
# Verizon : Verizon
# Tmobile : Tmobile
# accept : accept
# IMEI : IMEI
# guarantee : guarantee
# networks : network
# global : global
# international : international
# version : version
# said : said
# based : based
# SIM : SIM
# iphone : iphone
# 7 : 7
# until : until
# gave : gave
# bars : bar
# coverage : coverage
# Insert : Insert
# immediately : immediately
# dropped : dropped
# bar : bar
# service : service
# intermittently : intermittently
# lose : lose
# thought : thought
# crummy : crummy
# activated : activated
# instructions : instruction
# found : found
# online : online
# still : still
# able : able
# spent : spent
# HOURS : HOURS
# both : both
# tech : tech
# support : support
# won : won
# diminishing : diminishing
# reception : reception
# 75 : 75
# That : That
# IS : IS
# Wish : Wish
# model : model
# takes : take
# hours : hour
# charged : charged
# whereas : whereas
# say : say
# should : should
# Also : Also
# short : short
# fake : fake
# Swapping : Swapping
# existing : existing
# Metro : Metro
# okay : okay
# Huge : Huge
# warnings : warning
# package : package
# type : type
# right : right
# away : away
# opening : opening
# whiners : whiner
# moaning : moaning
# warned : warned
# There : There
# sim : sim
# slots : slot
# slot : slot
# closest : closest
# memory : memory
# card : card
# first : first
# nifty : nifty
# Display : Display
# speed : speed
# Camera : Camera
# seems : seems
# alright : alright
# mess : mess
# tired : tired
# slower : slower
# 4g : 4g
# ram : ram
# cpus : cpu
# 6g : 6g
# spry : spry
# 720 : 720
# checks : check
# boxes : box
# less : le
# One : One
# downer : downer
# wireless : wireless
# womp : womp
# UPDATE : UPDATE
# 11 : 11
# 21 : 21
# performance : performance
# looking : looking
# point : point
# Fast : Fast
# Shipping : Shipping
# shipped : shipped
# Mine : Mine
# came : came
# European : European
# charger : charger
# USA : USA
# spare : spare
# Other : Other
# beautiful : beautiful
# big : big
# heavy : heavy
# Carrier : Carrier
# Wingalpha : Wingalpha
# com : com
# bit : bit
# worried : worried
# wouldn : wouldn
# But : But
# anxiety : anxiety
# gone : gone
# once : once
# set : set
# worked : worked
# flawless : flawless
# Definitely : Definitely
# P : P
# pre : pre
# installed : installed
# protector : protector
# normally : normally
# noticed : noticed
# Update : Update
# months : month
# Still : Still
# From : From
# loyal : loyal
# LG : LG
# customer : customer
# V30 : V30
# sound : sound
# started : started
# lacking : lacking
# beats : beat
# spades : spade
# Battery : Battery
# best : best
# part : part
# used : used
# straight : straight
# data : data
# constantly : constantly
# before : before
# recharging : recharging
# Never : Never
# 300 : 300
# always : always
# buy : buy
# generations : generation
# behind : behind
# quirks : quirk
# And : And
# unfair : unfair
# compare : compare
# year : year
# Firstly : Firstly
# Chinese : Chinese
# security : security
# risk : risk
# Lately : Lately
# from : from
# Venmo : Venmo
# unauthorized : unauthorized
# sign : sign
# ins : in
# another : another
# breach : breach
# Secondly : Secondly
# MIUI : MIUI
# android : android
# customizable : customizable
# Flagship : Flagship
# Can : Can
# control : control
# game : game
# frame : frame
# rate : rate
# running : running
# moot : moot
# cool : cool
# apps : apps
# split : split
# bottom : bottom
# 50 : 50
# 66 : 66
# 33 : 33
# drag : drag
# float : float
# corner : corner
# window : window
# change : change
# aspect : aspect
# ratio : ratio
# resolution : resolution
# screenThirdly : screenThirdly
# sure : sure
# bands : band
# create : create
# APN : APN
# send : send
# txts : txts
# mms : mm
# fully : fully
# outgoing : outgoing
# January : January
# 2021 : 2021
# subscribers : subscriber
# VoLTE : VoLTE
# seem : seem
# 3G : 3G
# speeds : speed
# indicated : indicated
# status : status
# dig : dig
# settings : setting
# see : see
# downstream : downstream
# Wifi : Wifi
# Fourthly : Fourthly
# Looked : Looked
# everywhere : everywhere
# signal : signal
# Fifth : Fifth
# minor : minor
# things : thing
# too : too
# tall : tall
# 20 : 20
# LCD : LCD
# OLED : OLED
# Light : Light
# bleed : bleed
# thru : thru
# hand : hand
# brightness : brightness
# prefer : prefer
# better : better
# blacks : black
# grays : gray
# light : light
# bleeding : bleeding
# Sixth : Sixth
# transferring : transferring
# accounts : account
# seamless : seamless
# Every : Every
# generation : generation
# allowed : allowed
# transfer : transfer
# restore : restore
# email : email
# follow : follow
# main : main
# stuck : stuck
# Google : Google
# account : account
# Had : Had
# again : again
# unlike : unlike
# seamlessness : seamlessness
# process : process
# focused : focused
# negatives : negative
# positives : positive
# themselves : themselves
# For : For
# instance : instance
# rear : rear
# 64 : 64
# mp : mp
# 4k : 4k
# Conclusion : Conclusion
# holdover : holdover
# 5G : 5G
# Either : Either
# ll : ll
# go : go
# Edit : Edit
# 12 : 12
# 16 : 16
# Forgot : Forgot
# mention : mention
# waterproof : waterproof
# headphone : headphone
# jack : jack
# usually : usually
# why : why
# review : review
# skews : skews
# isn : isn
# many : many
# features : feature
# readily : readily
# explained : explained
# other : other
# repeating : repeating
# nervous : nervous
# ordering : ordering
# honestly : honestly
# 1k : 1k
# researching : researching
# affordable : affordable
# alternatives : alternative
# across : across
# decision : decision
# happy : happy
# head : head
# gives : give
# run : run
# money : money
# alternative : alternative
# Thank : Thank
# Robin : Robin
# Hood : Hood
# premium : premium
# frugal : frugal
# pleased : pleased
# wanted : wanted
# notifications : notification
# decent : decent
# storage : storage
# weeks : week
# standards : standard
# bigger : bigger
# banned : banned
# hence : hence
# photos : photo
# browse : browse
# internet : internet
# lasts : last
# normal : normal
# usage : usage
# Photos : Photos
# People : People
# nicely : nicely
# Seller : Seller
# fast : fast
# within : within
# standard : standard
# shipping : shipping
# Little : Little
# ur : ur
# palms : palm
# Initially : Initially
# Play : Play
# store : store
# however : however
# factory : factory
# reset : reset
# With : With
# space : space
# penny : penny
# simply : simply
# Galaxy : Galaxy
# Many : Many
# crazy : crazy
# plenty : plenty
# forever : forever
# must : must
# market : market
# below : below
# 800 : 800
# points : point
# insane : insane
# owned : owned
# Even : Even
# Razer : Razer
# impressed : impressed
# excellent : excellent
# boots : boot
# quick : quick
# flawlessbattery : flawlessbattery
# watching : watching
# netflix : netflix
# playing : playing
# taking : taking
# pics : pic
# texting : texting
# smsthe : smsthe
# ive : ive
# single : single
# pic : pic
# 48 : 48
# MB : MB
# yes : yes
# 48MB : 48MB
# angles : angle
# adjustment : adjustment
# flip : flip
# easily : easily
# x2 : x2
# x1 : x1
# magnification : magnification
# fumbling : fumbling
# BUT : BUT
# adjust : adjust
# ALL : ALL
# camerassettings : camerassettings
# BASE : BASE
# cleaning : cleaning
# uninstall : uninstall
# theirs : theirs
# option : option
# remove : remove
# IMO : IMO
# llegó : llegó
# antes : ante
# acordado : acordado
# Bien : Bien
# empacado : empacado
# tal : tal
# cual : cual
# descripción : descripción
# cellphone : cellphone
# sold : sold
# versión : versión
# indian : indian
# doesn : doesn
# 4G : 4G
# band : band
# REALLY : REALLY
# FEEL : FEEL
# CHEATED : CHEATED
# sell : sell
# M2003J6B2G : M2003J6B2G
# Global : Global
# However : However
# useless : useless
# Model : Model
# M2003J6A1I : M2003J6A1I
# DEMAND : DEMAND
# MY : MY
# REFUND : REFUND
# wipe : wipe
# date : date
# asks : asks
# unlock : unlock
# previous : previous
# password : password
# After : After
# finally : finally
# downloaded : downloaded
# iMyFone : iMyFone
# LockWiper : LockWiper
# computer : computer
# Eventually : Eventually
# asked : asked
# God : God
# hate : hate
# hassle : hassle
# Worth : Worth
# samsung : samsung
# Apple : Apple
# bucks : buck
# equipped : equipped
# IPS : IPS
# lcd : lcd
# equal : equal
# panels : panel
# needs : need
# improvement : improvement
# tooooooo : tooooooo
# loooooong : loooooong
# Lasts : Lasts
# 3days : 3days
# Moderate : Moderate
# joke : joke
# cheap : cheap
# radio : radio
# important : important
# xiaomi : xiaomi
# improved : improved
# vibration : vibration
# motor : motor
# haptic : haptic
# feedback : feedback
# removed : removed
# intensity : intensity
# soft : soft
# medium : medium
# hi : hi
# tapping : tapping
# way : way
# strength : strength
# All : All
# default : default
# seriously : seriously
# description : description
# International : International
# precise : precise
# exactly : exactly
# About : About
# menu : menu
# says : say
# isVersion : isVersion
# V11 : V11
# 0 : 0
# QJZEUXM : QJZEUXM
# MIUI11 : MIUI11
# According : According
# makes : make
# EEA : EEA
# tablet : tablet
# large : large
# capacity : capacity
# batteries : battery
# processor : processor
# comfortable : comfortable
# unqualified : unqualified
# USE : USE
# network : network
# signals : signal
# weak : weak
# times : time
# When : When
# intermittent : intermittent
# automatically : automatically
# interrupted : interrupted
# What : What
# value : value
# punches : punch
# above : above
# ways : way
# Great : Great
# cameras : camera
# smooth : smooth
# slightly : slightly
# colors : color
# pop : pop
# true : true
# flagship : flagship
# By : By
# biggest : biggest
# frequent : frequent
# outages : outage
# Sometimes : Sometimes
# disconnected : disconnected
# stop : stop
# working : working
# 30 : 30
# happens : happens
# fix : fix
# updated : updated
# miui : miui
# unlimited : unlimited
# beware : beware
# originally : originally
# 2018 : 2018
# uogradeable : uogradeable
# Blu : Blu
# Pure : Pure
# XL : XL
# Xioami : Xioami
# Unfortunately : Unfortunately
# shattered : shattered
# meant : meant
# went : went
# edition : edition
# available : available
# sad : sad
# comparison : comparison
# gesture : gesture
# relied : relied
# native : native
# recording : recording
# recordings : recording
# conversation : conversation
# apparently : apparently
# assume : assume
# lobbying : lobbying
# campaign : campaign
# stifle : stifle
# competition : competition
# Further : Further
# evidence : evidence
# indicate : indicate
# users : user
# left : left
# srticlrs : srticlrs
# activates : activates
# recorder : recorder
# catches : catch
# YOUR : YOUR
# faint : faint
# whisper : whisper
# caller : caller
# mouth : mouth
# tries : try
# heard : heard
# ear : ear
# same : same
# failed : failed
# Xl : Xl
# hails : hail
# Save : Save
# comparable : comparable
# low : low
# American : American
# respects : respect
# save : save
# trying : trying
# enable : enable
# absent : absent
# where : where
# roundabout : roundabout
# check : check
# VoWifi : VoWifi
# enabled : enabled
# different : different
# Calling : Calling
# least : least
# U : U
# S : S
# staff : staff
# unable : unable
# Jio : Jio
# AirTel : AirTel
# Considering : Considering
# advertised : advertised
# meet : meet
# expectations : expectation
# hurt : hurt
# eye : eye
# longer : longer
# whole : whole
# Moba : Moba
# System : System
# Start : Start
# Return : Return
# Took : Took
# Weeks : Weeks
# To : To
# Get : Get
# Part : Part
# Of : Of
# Money : Money
# Back : Back
# Around : Around
# Short : Short
# Original : Original
# Price : Price
# Give : Give
# Star : Star
# Screen : Screen
# Getting : Getting
# Bad : Bad
# They : They
# Steal : Steal
# Your : Your
# Terrible : Terrible
# Where : Where
# start : start
# rival : rival
# models : model
# including : including
# although : although
# common : common
# series : series
# stylus : stylus
# name : name
# misleading : misleading
# gigs : gig
# Octacore : Octacore
# 64mb : 64mb
# quad : quad
# lens : lens
# shoots : shoot
# expandable : expandable
# via : via
# MicroSD : MicroSD
# nearly : nearly
# bezel : bezel
# infinity : infinity
# curved : curved
# bother : bother
# despite : despite
# geek : geek
# ten : ten
# HUGE : HUGE
# 5000mAh : 5000mAh
# wake : wake
# wring : wring
# neck : neck
# browsing : browsing
# web : web
# YouTube : YouTube
# movie : movie
# Prime : Prime
# Netflix : Netflix
# doing : doing
# constitutes : constitutes
# glued : glued
# typically : typically
# remaining : remaining
# Note8 : Note8
# 3000mAh : 3000mAh
# required : required
# several : several
# throughout : throughout
# impressive : impressive
# extremely : extremely
# reboots : reboots
# noticeable : noticeable
# lag : lag
# closing : closing
# tax : tax
# such : such
# HD : HD
# players : player
# multiple : multiple
# background : background
# aren : aren
# cons : con
# none : none
# espec : espec
# mentioning : mentioning
# somewhat : somewhat
# bulky : bulky
# possible : possible
# spoiled : spoiled
# glass : glass
# construction : construction
# later : later
# bulk : bulk
# consistent : consistent
# brands : brand
# relative : relative
# week : week
# bothered : bothered
# TL : TL
# DR : DR
# powerful : powerful
# toe : toe
# 240 : 240
# doubtful : doubtful
# destroys : destroys
# incredible : incredible
# links : link
# open : open
# google : google
# browser : browser
# amazon : amazon
# saying : saying
# oops : oops
# wrong : wrong
# Upgrading : Upgrading
# Mi : Mi
# A1 : A1
# fan : fan
# debloated : debloated
# smoothly : smoothly
# versatile : versatile
# stabilization : stabilization
# 5x : 5x
# 6x : 6x
# wide : wide
# scenic : scenic
# views : view
# macro : macro
# supports : support
# GCam : GCam
# lapse : lapse
# photo : photo
# spheres : sphere
# gripe : gripe
# easy : easy
# Lycamobile : Lycamobile
# MVNO : MVNO
# provide : provide
# initial : initial
# impression : impression
# In : In
# summary : summary
# reasonable : reasonable
# elaborate : elaborate
# form : form
# opinionsFirst : opinionsFirst
# reflects : reflects
# differently : differently
# various : various
# Both : Both
# front : front
# gorilla : gorilla
# durable : durable
# clean : clean
# neat : neat
# fault : fault
# rim : rim
# plastic : plastic
# metal : metal
# First : First
# notice : notice
# cause : cause
# concern : concern
# appears : appears
# sturdy : sturdy
# obviously : obviously
# deep : deep
# contrast : contrast
# AMOLES : AMOLES
# XR : XR
# matches : match
# Outdoor : Outdoor
# visibility : visibility
# Software : Software
# Performance : Performance
# installs : installs
# booting : booting
# we : we
# ideally : ideally
# Hopefully : Hopefully
# soon : soon
# experienced : experienced
# slowness : slowness
# lags : lag
# installer : installer
# helpful : helpful
# drawer : drawer
# dedicated : dedicated
# bump : bump
# snappy : snappy
# intensive : intensive
# subway : subway
# surfers : surfer
# asphalt : asphalt
# complained : complained
# heats : heat
# iPhones : iPhones
# heating : heating
# concernCameras : concernCameras
# primary : primary
# MP : MP
# yet : yet
# try : try
# portrait : portrait
# regular : regular
# angle : angle
# night : night
# photography : photography
# Especially : Especially
# field : field
# view : view
# allows : allows
# snapped : snapped
# picture : picture
# 40 : 40
# standing : standing
# group : group
# close : close
# snap : snap
# gathering : gathering
# bring : bring
# Happy : Happy
# XS : XS
# Max : Max
# getting : getting
# capabilities : capability
# produces : produce
# blur : blur
# effect : effect
# reasonably : reasonably
# edge : edge
# Regarding : Regarding
# selfie : selfie
# seemed : seemed
# ok : ok
# artificial : artificial
# preferred : preferred
# farConnectivity : farConnectivity
# flawlessly : flawlessly
# Upload : Upload
# download : download
# WiFi : WiFi
# speedIt : speedIt
# monster : monster
# 4500 : 4500
# mAmp : mAmp
# damn : damn
# reached : reached
# done : done
# played : played
# watched : watched
# sent : sent
# messages : message
# browsed : browsed
# 18W : 18W
# North : North
# 27W : 27W
# Essential : Essential
# additions : addition
# possibly : possibly
# IR : IR
# blaster : blaster
# TVs : TVs
# micro : micro
# SD : SD
# expansion : expansion
# intend : intend
# retrieval : retrieval
# separately : separately
# arrives : arrives
# lastly : lastly
# mm : mm
# Hardly : Hardly
# ms : m
# shaping : shaping
# nowPlease : nowPlease
# insights : insight
# upgraded : upgraded
# mid : mid
# level : level
# consideration : consideration
# bunch : bunch
# searching : searching
# combination : combination
# cost : cost
# research : research
# unit : unit
# month : month
# user : user
# consumption : consumption
# personal : personal
# average : average
# Same : Same
# setup : setup
# shots : shot
# options : option
# Bluetooth : Bluetooth
# Headphone : Headphone
# Jack : Jack
# output : output
# interface : interface
# feels : feel
# setting : setting
# special : special
# ignore : ignore
# suggest : suggest
# anyone : anyone
# apple : apple
# nothing : nothing
# modified : modified
# filled : filled
# prevents : prevents
# centain : centain
# USB : USB
# installation : installation
# developer : developer
# then : then
# luck : luck
# register : register
# GPS : GPS
# location : location
# sketchy : sketchy
# illegal : illegal
# manufacturer : manufacturer
# Anytime : Anytime
# direct : direct
# log : log
# access : access
# hoops : hoop
# hiding : hiding
# stay : stay
# 2019 : 2019
# OS : OS
# black : black
# logs : log
# activity : activity
# creating : creating
# steps : step
# worst : worst
# fail : fail
# OnePlus : OnePlus
# 5T : 5T
# 7T : 7T
# pixel : pixel
# Asus : Asus
# Zen : Zen
# Everything : Everything
# legit : legit
# Got : Got
# arrival : arrival
# unscratched : unscratched
# Puerto : Puerto
# Rico : Rico
# wondering : wondering
# Claro : Claro
# Provided : Provided
# utterly : utterly
# forced : forced
# Witch : Witch
# bummer : bummer
# brick : brick
# care : care
# bricks : brick
# posted : posted
# beast : beast
# believe : believe
# match : match
# against : against
# daughter : daughter
# Came : Came
# beautifully : beautifully
# packaged : packaged
# ready : ready
# popped : popped
# fence : fence
# hesitate : hesitate
# zero : zero
# stars : star
# excited : excited
# upon : upon
# malfunctioning : malfunctioning
# freezing : freezing
# shutting : shutting
# itself : itself
# corrupted : corrupted
# turning : turning
# annoyed : annoyed
# garbage : garbage
# these : these
# usable : usable
# warranty : warranty
# expiring : expiring
# ZTE : ZTE
# ZMAX : ZMAX
# 2015 : 2015
# prior : prior
# fraction : fraction
# discharged : discharged
# Honor : Honor
# acting : acting
# delays : delay
# knew : knew
# Remi : Remi
# Thanks : Thanks
# frequency : frequency
# site : site
# how : how
# Version : Version
# versions : version
# wend : wend
# overpaid : overpaid
# prices : price
# blame : blame
# coronavirus : coronavirus
# lol : lol
# tell : tell
# regret : regret
# solid : solid
# Canon : Canon
# Mark : Mark
# II : II
# Selfies : Selfies
# lost : lost
# driving : driving
# Interstate : Interstate
# story : story
# office : office
# building : building
# Fingerprint : Fingerprint
# charm : charm
# Face : Face
# recognition : recognition
# giving : giving
# between : between
# technical : technical
# world : world
# amazes : amazes
# gb : gb
# difference : difference
# extra : extra
# duration : duration
# 32 : 32
# gm : gm
# external : external
# doubt : doubt
# forest : forest
# white : white
# Included : Included
# silicone : silicone
# bonus : bonus
# adapter : adapter
# ended : ended
# buying : buying
# capability : capability
# thinking : thinking
# considering : considering
# newer : newer
# announced : announced
# waste : waste
# Hoping : Hoping
# At : At
# Umidigi : Umidigi
# adequately : adequately
# returned : returned
# overseas : overseas
# feel : feel
# dish : dish
# order : order
# Maybe : Maybe
# someone : someone
# lazy : lazy
# search : search
# hope : hope
# meanwhile : meanwhile
# cellphones : cellphone
# Nova : Nova
# purchased : purchased
# eventually : eventually
# revert : revert
# checking : checking
# Right : Right
# seemless : seemless
# TMobile : TMobile
# multimedia : multimedia
# Haven : Haven
# person : person
# scrolling : scrolling
# buttery : buttery
# lightning : lightning
# Cricket : Cricket
# Wireless : Wireless
# rural : rural
# Maryland : Maryland
# truly : truly
# 220 : 220
# 750 : 750
# camper : camper
# finding : finding
# exploring : exploring
# expecting : expecting
# happier : happier
# Feels : Feels
# sleek : sleek
# hands : hand
# navigate : navigate
# ton : ton
# bloat : bloat
# ware : ware
# 24 : 24
# moving : moving
# forward : forward
# DDR : DDR
# 6gb : 6gb
# newest : newest
# 8gb : 8gb
# blazing : blazing
# stick : stick
# xiachow : xiachow
# S4 : S4
# anticipated : anticipated
# s21 : s21
# disappointment : disappointment
# downgrade : downgrade
# s20 : s20
# prepurchased : prepurchased
# realized : realized
# Some : Some
# include : include
# Resolution : Resolution
# QHD : QHD
# 3200 : 3200
# 1440 : 1440
# Ram : Ram
# 12GB : 12GB
# GB3 : GB3
# gone4 : gone4
# Pressure : Pressure
# testing : testing
# CPU : CPU
# 888 : 888
# 865 : 865
# consumes : consumes
# heated : heated
# Case : Case
# material : material
# downgraded : downgraded
# plastic6 : plastic6
# Missing : Missing
# headset : headset
# s21In : s21In
# significantly : significantly
# wants : want
# cable : cable
# ends : end
# connections : connection
# aux : aux
# Very : Very
# disappointing : disappointing
# paid : paid
# 700 : 700
# 92 : 92
# drops : drop
# Surprise : Surprise
# purchase : purchase
# Worked : Worked
# couls : couls
# powered : powered
# compared : compared
# Memory : Memory
# Quite : Quite
# Brand : Brand
# upgrading : upgrading
# 2017 : 2017
# J7 : J7
# V : V
# Does : Does
# Loving : Loving
# Again : Again
# coming : coming
# perks : perk
# purchasing : purchasing
# skeptical : skeptical
# SUPER : SUPER
# mint : mint
# condition : condition
# Fully : Fully
# UNLOCKED : UNLOCKED
# Network : Network
# Recommendation : Recommendation
# 10Packaging : 10Packaging
# 10Respect : 10Respect
# Jamaica : Jamaica
# Muy : Muy
# bueno : bueno
# Euro : Euro
# Nord : Nord
# N10 : N10
# minded : minded
# SnapDragon : SnapDragon
# 690 : 690
# capable : capable
# Adreno : Adreno
# 619L : 619L
# GPU : GPU
# latest : latest
# laggy : laggy
# COD : COD
# Warzone : Warzone
# Coming : Coming
# 2GB : 2GB
# flagships : flagship
# 90Hz : 90Hz
# refresh : refresh
# feeling : feeling
# faster : faster
# Gorilla : Gorilla
# Glass : Glass
# water : water
# resistant : resistant
# Pixel : Pixel
# 4A : 4A
# Oxygen : Oxygen
# optimization : optimization
# Game : Game
# Fnatic : Fnatic
# cut : cut
# watch : watch
# movies : movie
# directs : directs
# resources : resource
# choose : choose
# Includes : Includes
# total : total
# included : included
# 3D : 3D
# Benchmarks : Benchmarks
# Slingshot : Slingshot
# Extreme : Extreme
# interested : interested
# raw : raw
# numbers : number
# handling : handling
# tougher : tougher
# applications : application
# includes : includes
# Enjoy : Enjoy
# complaints : complaint
# warp : warp
# shuts : shuts
# twice : twice
# during : during
# alarms : alarm
# morning : morning
# dual : dual
# tray : tray
# recommended : recommended
# ATT : ATT
# EE : EE
# Absolutely : Absolutely
# files : file
# slight : slight
# inconvenience : inconvenience
# Charger : Charger
# pin : pin
# wobbly : wobbly
# Dual : Dual
# smart : smart
# India : India
# sims : sims
# travel : travel
# Sim : Sim
# UK : UK
# Supplier : Supplier
# delivery : delivery
# stated : stated
# sim2 : sim2
# currently : currently
# patchy : patchy
# anyway : anyway
# mostly : mostly
# Sims : Sims
# verizon : verizon
# THIS : THIS
# AN : AN
# BUDGET : BUDGET
# PHONE : PHONE
# oneplus : oneplus
# who : who
# higher : higher
# accidentally : accidentally
# myself : myself
# ONLY : ONLY
# seller : seller
# title : title
# clearer : clearer
# CDMA : CDMA
# basing : basing
# rating : rating
# exact : exact
# besides : besides
# switched : switched
# NORD : NORD
# plus : plus
# sd : sd
# Manufactures : Manufactures
# hybrid : hybrid
# blurry : blurry
# Havent : Havent
# till : till
# hors : hors
# Its : Its
# plan : plan
# Needed : Needed
# swipe : swipe
# nor : nor
# sprint : sprint
# tine : tine
# benefic : benefic
# Pesimo : Pesimo
# mes : me
# compre : compre
# comenzo : comenzo
# escucharse : escucharse
# audicion : audicion
# llamas : llama
# costumer : costumer
# reemplazo : reemplazo
# devolucion : devolucion
# te : te
# dicen : dicen
# areglarlo : areglarlo
# mas : ma
# opcion : opcion
# caro : caro
# cuesta : cuesta
# verdad : verdad
# pa : pa
# comprar : comprar
# 31 : 31
# IF : IF
# YOU : YOU
# DIDN : DIDN
# RECEIVE : RECEIVE
# WIRED : WIRED
# AKG : AKG
# headphones : headphone
# add : add
# customers : customer
# 726 : 726
# 7864 : 7864
# request : request
# yours : yours
# free : free
# mine : mine
# scammed : scammed
# wired : wired
# grain : grain
# salt : salt
# rendered : rendered
# fairly : fairly
# expensive : expensive
# S20 : S20
# Ultra : Ultra
# obsolete : obsolete
# units : unit
# pros : pro
# IPhone : IPhone
# max : max
# 4XL : 4XL
# bests : best
# wider : wider
# ultra : ultra
# example : example
# outstanding : outstanding
# perfect : perfect
# conditions : condition
# dunno : dunno
# cropping : cropping
# yield : yield
# result : result
# modes : mode
# pen : pen
# useful : useful
# notes : note
# except : except
# eventhough : eventhough
# selling : selling
# Yup : Yup
# design : design
# wise : wise
# putting : putting
# covers : cover
# personally : personally
# slim : slim
# transparent : transparent
# added : added
# gimmicky : gimmicky
# loved : loved
# share : share
# show : show
# cast : cast
# TV : TV
# chrome : chrome
# attached : attached
# certain : certain
# mentioned : mentioned
# anywhere : anywhere
# outdoor : outdoor
# next : next
# instead : instead
# surprise : surprise
# smaller : smaller
# practical : practical
# Now : Now
# guess : guess
# preface : preface
# supporting : supporting
# devices : device
# near : near
# desired : desired
# soooooo : soooooo
# slow : slow
# searches : search
# load : load
# Hotspot : Hotspot
# downright : downright
# awful : awful
# sub : sub
# Leica : Leica
# figured : figured
# scam : scam
# earbuds : earbuds
# clone : clone
# connector : connector
# Don : Don
# spectacular : spectacular
# 120hz : 120hz
# maybe : maybe
# sec : sec
# worthless : worthless
# Scrolling : Scrolling
# page : page
# posts : post
# information : information
# diagnosed : diagnosed
# He : He
# tested : tested
# his : his
# test : test
# additional : additional
# 15 : 15
# connect : connect
# starting : starting
# advice : advice
# markets : market
# mean : mean
# falls : fall
# Mate : Mate
# compete : compete
# hater : hater
# solidifies : solidifies
# viewpoint : viewpoint
# Won : Won
# mistake : mistake
# defense : defense
# isolated : isolated
# incident : incident
# simple : simple
# Best : Best
# Busy : Busy
# Slow : Slow
# city : city
# happen : happen
# period : period
# consumers : consumer
# swapping : swapping
# girlfriend : girlfriend
# directly : directly
# voicemail : voicemail
# hit : hit
# idea : idea
# hourly : hourly
# employees : employee
# realm : realm
# troubleshoot : troubleshoot
# switch : switch
# min : min
# couple : couple
# delayed : delayed
# response : response
# SMH : SMH
# confused : confused
# whether : whether
# ie : ie
# toggle : toggle
# buddy : buddy
# mind : mind
# boggling : boggling
# self : self
# employed : employed
# lifeline : lifeline
# release : release
# Such : Such
# shame : shame
# history : history
# HTML5 : HTML5
# defect : defect
# registering : registering
# circular : circular
# failure : failure
# 1500 : 1500
# IMPORTANT : IMPORTANT
# EDIT : EDIT
# Noticed : Noticed
# occurring : occurring
# phenomenon : phenomenon
# caused : caused
# Steelie : Steelie
# magnetic : magnetic
# mount : mount
# encounter : encounter
# score : score
# reflect : reflect
# Purchased : Purchased
# damaged : damaged
# Deceptively : Deceptively
# protectors : protector
# Pay : Pay
# attention : attention
# stopped : stopped
# Hz : Hz
# probably : probably
# crown : crown
# key : key
# bumps : bump
# namely : namely
# planning : planning
# spend : spend
# Spigen : Spigen
# effectively : effectively
# reduces : reduces
# allow : allow
# sit : sit
# flat : flat
# desk : desk
# IP68 : IP68
# dust : dust
# protection : protection
# saw : saw
# stat : stat
# recently : recently
# report : report
# incurring : incurring
# damage : damage
# specifically : specifically
# interesting : interesting
# middle : middle
# class : class
# afford : afford
# pocket : pocket
# everyday : everyday
# cars : car
# houses : house
# clothes : clothes
# swing : swing
# Lastly : Lastly
# offer : offer
# exceed : exceed
# products : product
# guy : guy
# specific : specific
# somebody : somebody
# machine : machine
# computing : computing
# Whites : Whites
# dull : dull
# rez : rez
# impresionante : impresionante
# otro : otro
# habia : habia
# unas : unas
# espectaculares : espectaculares
# ademas : ademas
# trabajo : trabajo
# lapiz : lapiz
# van : van
# genial : genial
# encantado : encantado
# opened : opened
# small : small
# scratches : scratch
# body : body
# previously : previously
# soled : soled
# reshipped : reshipped
# Received : Received
# false : false
# advertisement : advertisement
# 4gb : 4gb
# upset : upset
# ripped : ripped
# buyer : buyer
# Box : Box
# sealed : sealed
# stickers : sticker
# spec : spec
# suspicious : suspicious
# Customer : Customer
# BREED : BREED
# utter : utter
# garbageWill : garbageWill
# THEY : THEY
# CHANGED : CHANGED
# IT : IT
# TO : TO
# NOT : NOT
# SHOW : SHOW
# CHARGE : CHARGE
# SAME : SAME
# PRICE : PRICE
# FOR : FOR
# 4GB : 4GB
# wife : wife
# S8 : S8
# asap : asap
# A20s : A20s
# son : son
# A30s : A30s
# regarding : regarding
# cancelled : cancelled
# A51 : A51
# primarily : primarily
# uses : us
# following : following
# bands2 : bands2
# 71The : 71The
# list : list
# gladly : gladly
# willing : willing
# ensure : ensure
# maximum : maximum
# connectivity : connectivity
# parts : part
# connectivityThe : connectivityThe
# s10 : s10
# microphone : microphone
# loves : love
# speakerphone : speakerphone
# her : her
# s8 : s8
# occasionally : occasionally
# mic : mic
# pick : pick
# further : further
# helps : help
# Reception : Reception
# We : We
# measured : measured
# signel : signel
# asu : asu
# areas : area
# weaker : weaker
# ScreenSamsung : ScreenSamsung
# AMOLEDs : AMOLEDs
# business : business
# relieved : relieved
# us : u
# robust : robust
# protect : protect
# indistuingishable : indistuingishable
# tiny : tiny
# pinhole : pinhole
# entire : entire
# optical : optical
# rather : rather
# infrasonic : infrasonic
# talking : talking
# milliseconds : millisecond
# General : General
# usabilityMy : usabilityMy
# gamer : gamer
# she : she
# productivity : productivity
# transition : transition
# multitasks : multitasks
# shred : shred
# concerned : concerned
# processing : processing
# Switch : Switch
# transfered : transfered
# Once : Once
# rebooted : rebooted
# CameraThe : CameraThe
# beefy : beefy
# shooter : shooter
# hard : hard
# setups : setup
# Picture : Picture
# transitioning : transitioning
# instant : instant
# shutter : shutter
# luckily : luckily
# BatteryI : BatteryI
# admit : admit
# 4000mah : 4000mah
# 3500mah : 3500mah
# typical : typical
# percentage : percentage
# scattered : scattered
# busy : busy
# Mint : Mint
# configuring : configuring
# researched : researched
# website : website
# ask : ask
# question : question
# Spanish : Spanish
# chose : chose
# English : English
# Auto : Auto
# preinstalled : preinstalled
# Uninstalling : Uninstalling
# reinstalling : reinstalling
# bugs : bug
# lower : lower
# blue : blue
# cricket : cricket
# Pennsylvania : Pennsylvania
# learning : learning
# differences : difference
# SM : SM
# A515F : A515F
# DS : DS
# internal : internal
# DSN : DSN
# Prism : Prism
# Crush : Crush
# Black : Black
# April : April
# 2020 : 2020
# doorstep : doorstep
# accessories : accessory
# configuration : configuration
# beginning : beginning
# Settings : Settings
# Mode : Mode
# Natural : Natural
# Vivid : Vivid
# Dark : Dark
# Biometrics : Biometrics
# Security : Security
# Fingerprints : Fingerprints
# move : move
# reads : read
# lines : line
# fingers : finger
# login : login
# DID : DID
# dogs : dog
# nose : nose
# WOW : WOW
# stunning : stunning
# lizard : lizard
# taken : taken
# Calls : Calls
# strong : strong
# registered : registered
# dad : dad
# pass : pas
# Aside : Aside
# Feitenn : Feitenn
# Metal : Metal
# ASIN : ASIN
# B0839C38GM : B0839C38GM
# DOES : DOES
# together : together
# placed : placed
# Tempered : Tempered
# B082S7NCB8 : B082S7NCB8
# gig : gig
# might : might
# wont : wont
# iemi : iemi
# likely : likely
# dont : dont
# att : att
# couldnt : couldnt
# a50 : a50
# early : early
# censor : censor
# Motorola : Motorola
# lg : lg
# fits : fit
# bells : bell
# whistles : whistle
# writing : writing
# rainbow : rainbow
# reflection : reflection
# Another : Another
# responsiveness : responsiveness
# handles : handle
# throw : throw
# id : id
# chance : chance
# S9 : S9
# perform : perform
# surpasses : surpasses
# shot : shot
# eliminating : eliminating
# winner : winner
# continue : continue
# These : These
# unbeatable : unbeatable
# processors : processor
# Saludos : Saludos
# compré : compré
# metí : metí
# car : car
# PCS : PCS
# refleja : refleja
# realizar : realizar
# llamadas : llamadas
# reseña : reseña
# dice : dice
# debloqueado : debloqueado
# fábrica : fábrica
# obnoxious : obnoxious
# boot : boot
# loader : loader
# cache : cache
# partition : partition
# starts : start
# reinstall : reinstall
# dialer : dialer
# asian : asian
# characters : character
# Replaced : Replaced
# contacts : contact
# Text : Text
# messaging : messaging
# constant : constant
# nag : nag
# screens : screen
# cloud : cloud
# Fixed : Fixed
# replacing : replacing
# kept : kept
# popups : popups
# activate : activate
# disabling : disabling
# awkward : awkward
# minute : minute
# instantaneous : instantaneous
# Excellent : Excellent
# Runs : Runs
# others : others
# wash : wash
# Neither : Neither
# positive : positive
# Probably : Probably
# root : root
# miserable : miserable
# felt : felt
# voLTE : voLTE
# alphabetize : alphabetize
# closes : close
# layer : layer
# suits : suit
# económico : económico
# rápido : rápido
# resistente : resistente
# MTK : MTK
# Helio : Helio
# G85 : G85
# alto : alto
# rendimiento : rendimiento
# octa : octa
# core : core
# alta : alta
# capacidad : capacidad
# G : G
# Wi : Wi
# Fi : Fi
# publicidad : publicidad
# falsa : falsa
# ese : ese
# 64GB : 64GB
# vamos : vamos
# ver : ver
# recompensar : recompensar
# tener : tener
# demandar : demandar
# falcedad : falcedad
# Yo : Yo
# pedi : pedi
# desde : desde
# Republica : Republica
# Dominicana : Dominicana
# bastante : bastante
# devolverlo : devolverlo
# Le : Le
# estrella : estrella
# darle : darle
# cero : cero
# Lots : Lots
# choice : choice
# cases : case
# Easy : Easy
# 35 : 35
# recharge : recharge
# prints : print
# Mavic : Mavic
# Mini : Mini
# DJI : DJI
# drone : drone
# outside : outside
# 128gb : 128gb
# Sound : Sound
# oldest : oldest
# DSLR : DSLR
# Over : Over
# house : house
# exceptional : exceptional
# bargain : bargain
# widely : widely
# notify : notify
# viber : viber
# ebay : ebay
# trade : trade
# stocks : stock
# realize : realize
# messed : messed
# sales : sale
# ads : ad
# spyware : spyware
# yourself : yourself
# Cameras : Cameras
# mediocre : mediocre
# 2xl : 2xl
# settled : settled
# Plenty : Plenty
# 256mb : 256mb
# vivid : vivid
# detail : detail
# Night : Night
# magnets : magnet
# seal : seal
# operating : operating
# roughly : roughly
# driver : driver
# trouble : trouble
# swap : swap
# aging : aging
# honor : honor
# 7X : 7X
# p : p
# 57 : 57
# HIDDEN : HIDDEN
# SETTINGS : SETTINGS
# Ads : Ads
# appear : appear
# MI : MI
# APPS : APPS
# Cellular : Cellular
# gigahertz : gigahertz
# router : router
# 340 : 340
# megabytes : megabyte
# capping : capping
# border : border
# glad : glad
# OTG : OTG
# inn : inn
# Hope : Hope
# Too : Too
# somehow : somehow
# relatively : relatively
# offers : offer
# Their : Their
# convinced : convinced
# sensors : sensor
# ambient : ambient
# outright : outright
# given : given
# privacy : privacy
# amount : amount
# programs : program
# kindly : kindly
# benefit : benefit
# agreement : agreement
# Do : Do
# gallery : gallery
# agree : agree
# soul : soul
# book : book
# music : music
# player : player
# file : file
# explorer : explorer
# chances : chance
# family : family
# folder : folder
# random : random
# advertisements : advertisement
# Doing : Doing
# aware : aware
# stealing : stealing
# offloading : offloading
# servers : server
# abroad : abroad
# offender : offender
# meaning : meaning
# sat : sat
# agreements : agreement
# Cleaner : Cleaner
# Why : Why
# application : application
# supposed : supposed
# cached : cached
# empty : empty
# trash : trash
# bin : bin
# identifiers : identifier
# AND : AND
# MESSAGES : MESSAGES
# countries : country
# proven : proven
# steal : steal
# age : age
# plans : plan
# profit : profit
# trust : trust
# similar : similar
# companies : company
# 1000 : 1000
# dollars : dollar
# performed : performed
# blown : blown
# vs : v
# gotten : gotten
# friend : friend
# him : him
# ability : ability
# friendly : friendly
# endless : endless
# themes : theme
# Only : Only
# downside : downside
# lightly : lightly
# distance : distance
# wallet : wallet
# cracks : crack
# towards : towards
# bothers : bother
# careful : careful
# otherwise : otherwise
# Quality : Quality
# Levels : Levels
# Moto : Moto
# displays : display
# Love : Love
# skin : skin
# Takes : Takes
# learn : learn
# customization : customization
# rid : rid
# recommendations : recommendation
# Control : Control
# center : center
# swipes : swipe
# Florida : Florida
# Red : Red
# Pocket : Pocket
# GSMA : GSMA
# towers : tower
# Volte : Volte
# mapping : mapping
# 17 : 17
# Most : Most
# states : state
# 17even : 17even
# listing : listing
# v : v
# town : town
# stronger : stronger
# slipping : slipping
# configured : configured
# correctly : correctly
# Unlocked : Unlocked
# isnt : isnt
# dosen : dosen
# Argentina : Argentina
# Please : Please
# Movistar : Movistar
# Tuenti : Tuenti
# please : please
# questions : question
# experts : expert
# Beautiful : Beautiful
# compra : compra
# articulo : articulo
# sonido : sonido
# cámara : cámara
# perfectas : perfecta
# condiciones : condiciones
# duda : duda
# algúna : algúna
# volvería : volvería
# esperado : esperado
# vidrio : vidrio
# templado : templado
# gr8 : gr8
# Elegant : Elegant
# Pokemon : Pokemon
# Go : Go
# superb : superb
# Top : Top
# Gun : Gun
# Trailer : Trailer
# Super : Super
# Poco : Poco
# X3 : X3
# funny : funny
# cartoonish : cartoonish
# image : image
# animation : animation
# eBay : eBay
# Make : Make
# Store : Store
# Services : Services
# rely : rely
# China : China
# makers : maker
# releasing : releasing
# local : local
# classmate : classmate
# Johnny : Johnny
# fight : fight
# Peter : Peter
# messy : messy
# each : each
# becomes : becomes
# Simplesmente : Simplesmente
# fantástico : fantástico
# Este : Este
# foi : foi
# meu : meu
# primeiro : primeiro
# da : da
# eu : eu
# estou : estou
# sem : sem
# palavras : palavras
# descrever : descrever
# quão : quão
# incrível : incrível
# tem : tem
# sido : sido
# experiência : experiência
# O : O
# aparelho : aparelho
# é : é
# dúvida : dúvida
# muito : muito
# bom : bom
# E : E
# entrega : entrega
# chegou : chegou
# prazo : prazo
# Produto : Produto
# ótima : ótima
# qualidade : qualidade
# não : não
# arrependo : arrependo
# ter : ter
# comprado : comprado
# recomendo : recomendo
# Loja : Loja
# tbm : tbm
# boa : boa
# Chegou : Chegou
# em : em
# dias : dia
# Perfeito : Perfeito
# Celular : Celular
# veio : veio
# queimado : queimado
# vendedor : vendedor
# quer : quer
# trocar : trocar
# Péssimo : Péssimo
# atendimento : atendimento
# nem : nem
# entrou : entrou
# contato : contato
# comigo : comigo
# apenas : apenas
# mandou : mandou
# mail : mail
# incrivel : incrivel
# você : você
# quiser : quiser
# ele : ele
# canal : canal
# falanerd : falanerd
# Parabéns : Parabéns
# só : só
# pelo : pelo
# final : final
# semana : semana
# na : na
# quinta : quinta
# recebi : recebi
# segunda : segunda
# feira : feira
# sábado : sábado
# já : já
# estava : estava
# correios : correios
# minha : minha
# cidade : cidade
# são : são
# Paulo : Paulo
# Pirapora : Pirapora
# mg : mg
# Valeu : Valeu
# amigos : amigo
# mais : mais
# um : um
# cliente : cliente
# satisfeito : satisfeito
# vou : vou
# divulgar : divulgar
# link : link
# indicar : indicar
# certeza : certeza
# Panamá : Panamá
# datos : datos
# maravilla : maravilla
# Speakers : Speakers
# improve : improve
# Plus : Plus
# 5Edit : 5Edit
# Almost : Almost
# SOMETIMES : SOMETIMES
# delay : delay
# exit : exit
# widgets : widget
# resolved : resolved
# team : team
# Symmetrical : Symmetrical
# bezels : bezel
# punch : punch
# Using : Using
# Fastest : Fastest
# easiest : easiest
# Doesn : Doesn
# Bueno : Bueno
# Ese : Ese
# cuanto : cuanto
# diseño : diseño
# tons : ton
# current : current
# range : range
# hardly : hardly
# Plays : Plays
# BYOD : BYOD
# failing : failing
# 71 : 71
# Better : Better
# A71 : A71
# gestures : gesture
# Gpay : Gpay
# Vibration : Vibration
# thin : thin
# ID : ID
# recognize : recognize
# Toma : Toma
# increíbles : increíbles
# profundidad : profundidad
# IA : IA
# trabaja : trabaja
# elección : elección
# los : los
# colores : colores
# velocidad : velocidad
# muchas : muchas
# opciones : opciones
# personalización : personalización
# fuerte : fuerte
# vaya : vaya
# sabe : sabe
# destacarse : destacarse
# sus : sus
# atributos : atributos
# suave : suave
# gráfica : gráfica
# ligero : ligero
# Estoy : Estoy
# opción : opción

# %%
from nltk.stem import LancasterStemmer
stemmer = LancasterStemmer()
for i in unique_words:
    print("{} : {}".format(i, stemmer.stem(i)))
# Out:
# Lo : lo
# primero : primero
# he : he
# de : de
# decir : decir
# que : que
# esta : est
# opinión : opinión
# es : es
# la : la
# un : un
# comprador : comprad
# real : real
# nadie : nady
# me : me
# ha : ha
# pagado : pagado
# por : por
# ella : ell
# ni : ni
# ofrecido : ofrecido
# productos : producto
# gratis : grat
# digo : digo
# porque : porqu
# le : le
# pongo : pongo
# 5 : 5
# estrellas : estrella
# al : al
# Xiaomi : xiaom
# Redmi : redm
# Note : not
# 10 : 10
# Pro : pro
# 6 : 6
# GB : gb
# RAM : ram
# y : y
# 128 : 128
# almacenamiento : almacenamiento
# interno : interno
# Adquirido : adquirido
# hace : hac
# par : par
# semanas : semana
# el : el
# teléfono : teléfono
# está : está
# resultando : resultando
# tan : tan
# satisfactorio : satisfactorio
# como : como
# mi : mi
# anterior : antery
# Huawei : huawe
# P30 : p30
# Lite : lit
# caído : caído
# en : en
# acto : acto
# servicio : servicio
# pero : pero
# con : con
# añadido : añadido
# más : más
# memoria : memor
# procesador : procesad
# potente : pot
# una : un
# pantalla : pantall
# mayor : may
# No : no
# se : se
# calienta : calient
# nada : nad
# sensor : sens
# huellas : huella
# lateral : lat
# funciona : funcion
# a : a
# perfección : perfección
# reconocimiento : reconocimiento
# facial : fac
# va : va
# tiro : tiro
# conjunto : conjunto
# cámaras : cámaras
# Puedes : pued
# hacer : hac
# fotos : foto
# incluso : incluso
# máximo : máximo
# resolución : resolución
# 108 : 108
# mpx : mpx
# luego : luego
# recortes : recort
# pudiendo : pudiendo
# así : así
# suplir : suplir
# perfectamente : perfecta
# falta : falt
# pequeño : pequeño
# zoom : zoom
# óptico : óptico
# Los : los
# juegos : juego
# ejecutan : ejecut
# sin : sin
# problemas : problema
# streaming : streaming
# muy : muy
# fluido : fluido
# La : la
# carga : carg
# su : su
# batería : baterí
# 000 : 000
# mAh : mah
# rápida : rápida
# NFC : nfc
# De : de
# momento : momento
# estoy : estoy
# satisfecho : satisfecho
# Spedizione : sped
# ottima : ottim
# ordinato : ordinato
# domenica : domenic
# e : e
# ricevuto : ricevuto
# martedì : martedì
# Aveva : avev
# app : ap
# di : di
# Windtre : windt
# installata : installat
# non : non
# ho : ho
# capito : capito
# si : si
# tratti : tratt
# versione : vert
# brandizzata : brandizzat
# o : o
# globale : glob
# ad : ad
# ogni : ogn
# modo : modo
# aveva : avev
# solo : solo
# quella : quell
# è : è
# bastato : bastato
# rimuoverla : rimuoverl
# Telefono : telefono
# piuttosto : piuttosto
# grande : grand
# fotocamera : fotocamer
# ed : ed
# buona : buon
# usabilità : usabilità
# per : per
# uso : uso
# quotidiano : quotidiano
# schermo : schermo
# amoled : amol
# davvero : davvero
# stupendo : stupendo
# Peccato : peccato
# che : che
# ci : ci
# sia : sia
# l : l
# opzione : opz
# disabilitare : disabilit
# ricarica : ricaric
# rapida : rapid
# bisognerebbe : bisognereb
# procurarsi : procurars
# caricatore : car
# più : più
# lento : lento
# parte : part
# Vedremo : vedremo
# riscontrerò : riscontrerò
# il : il
# tanto : tanto
# discusso : discusso
# problema : problem
# sensore : sens
# prossimità : prossimità
# avendo : avendo
# effettuato : effettuato
# poche : poch
# telefonate : telefon
# finora : finor
# riscontrato : riscontrato
# ma : ma
# escluso : escluso
# lo : lo
# riscontri : riscontr
# Si : si
# spera : sper
# questi : quest
# problemi : problem
# vengano : vengano
# risolti : risolt
# presto : presto
# gli : gli
# aggiornamenti : aggiornament
# della : dell
# Miui : miu
# Il : il
# telefono : telefono
# bomba : bomb
# bello : bello
# unica : unic
# pecca : pecc
# sta : sta
# sulla : sull
# batteria : batter
# pensavo : pensavo
# durasse : durass
# visto : visto
# 5020 : 5020
# Deluso : deluso
# dalla : dall
# Overall : overal
# I : i
# have : hav
# this : thi
# phone : phon
# now : now
# for : for
# few : few
# days : day
# and : and
# it : it
# s : s
# good : good
# The : the
# battery : battery
# is : is
# great : gre
# works : work
# fine : fin
# but : but
# there : ther
# one : on
# major : maj
# problem : problem
# think : think
# that : that
# the : the
# reason : reason
# star : star
# fact : fact
# when : when
# you : you
# re : re
# on : on
# call : cal
# screen : screen
# not : not
# turned : turn
# off : off
# can : can
# push : push
# some : som
# buttons : button
# with : with
# your : yo
# face : fac
# It : it
# happened : hap
# to : to
# mutes : mut
# my : my
# or : or
# turn : turn
# loudspeaker : loudspeak
# put : put
# hold : hold
# issue : issu
# shows : show
# product : produc
# mature : mat
# enough : enough
# m : m
# quite : quit
# disappointed : disappoint
# Otherwise : otherw
# rest : rest
# does : doe
# job : job
# so : so
# far : far
# cosa : cos
# dato : dato
# sui : sui
# nervi : nerv
# appartentemente : appart
# c : c
# rimedio : rimedio
# disattiva : disattiv
# durante : dur
# chiamate : chiam
# funziona : funzion
# MAI : mai
# bene : ben
# attivando : attivando
# cose : cos
# caso : caso
# spesso : spesso
# tiene : tien
# spalla : spall
# impazzisce : impazzisc
# volte : volt
# stacca : stacc
# chiamata : chiamat
# attiva : attiv
# mute : mut
# inspiegabilmente : inspieg
# flash : flash
# PERCHÈ : perchè
# creandomi : creandom
# pochi : poch
# disagi : disag
# anche : anch
# audio : audio
# Whatsapp : whatsap
# Per : per
# resto : resto
# sono : sono
# abbastanza : abbastanz
# soddisfatto : soddisfatto
# dura : dur
# quasi : quas
# due : due
# giorni : giorn
# pieni : pien
# utilizzando : utilizzando
# in : in
# prevalenza : prevalenz
# social : soc
# hotspot : hotspot
# acceso : acceso
# almeno : almeno
# 3 : 3
# ore : or
# giorno : giorno
# fa : fa
# troppo : troppo
# rimpiangere : rimpiang
# top : top
# gamma : gamm
# Mi10T : mi10t
# processore : process
# scattante : scat
# ne : ne
# fanno : fanno
# ottimo : ottimo
# fascia : fasc
# media : med
# molto : molto
# brillante : bril
# essendo : essendo
# super : sup
# AMOLED : amol
# Altri : altr
# difetti : difett
# fotocamere : fotocam
# sporgono : sporgono
# come : com
# balcone : balcon
# bisogno : bisogno
# cover : cov
# importante : import
# evitare : evit
# fracassino : fracassino
# già : già
# citato : citato
# SENSORE : sens
# DI : di
# PROSSIMITA : prossimit
# qualità : qualità
# delle : del
# foto : foto
# buio : buio
# rispeto : rispeto
# altri : altr
# concorrenti : concorrent
# camera : camer
# grandangolare : grandangol
# Valido : valido
# nel : nel
# complesso : complesso
# delusione : delud
# totale : tot
# sopra : sopr
# Amazon : amazon
# garanzia : garanz
# arrivato : arrivato
# anticipo : anticipo
# ben : ben
# imballato : imballato
# 4 : 4
# stelle : stel
# Arrivato : arrivato
# prima : prim
# del : del
# previsto : previsto
# complimenti : compliment
# venditore : vendit
# sempre : sempr
# Dopo : dopo
# qualche : qualch
# utilizzo : utilizzo
# posso : posso
# dire : dir
# smartphone : smartphon
# veloce : veloc
# dopo : dopo
# Fotocamera : fotocamer
# eccezionali : eccezional
# Doveva : dovev
# arrivare : arriv
# tra : tra
# 27 : 27
# 29 : 29
# aprile : april
# invece : invec
# sorpresa : sorpres
# 26 : 26
# Por : por
# defecto : defecto
# viene : vien
# 60 : 60
# h : h
# cambié : cambié
# 120 : 120
# duró : duró
# bateria : bater
# medio : medio
# diaEl : diael
# senson : senson
# proximidad : proximidad
# para : par
# hablar : habl
# no : no
# apaga : apag
# acercarlo : acercarlo
# oreja : orej
# cada : cad
# vez : vez
# hablopulse : hablopuls
# todo : todo
# Al : al
# altavoz : altavoz
# quejan : ques
# todos : todo
# escucha : escuch
# tengo : tengo
# poner : pon
# micrófono : micrófono
# cm : cm
# entienden : entiend
# duración : duración
# dos : dos
# días : día
# poco : poco
# Cellulare : cellul
# consegna : consegn
# stata : stat
# iper : ip
# messo : messo
# soltanto : soltanto
# Imballaggio : imballaggio
# accurato : accurato
# sicuro : sicuro
# Works : work
# metro : metro
# pay : pay
# fee : fee
# Not : not
# negative : neg
# just : just
# Pros : pro
# looks : look
# display : display
# comes : com
# substantial : subst
# case : cas
# life : lif
# Cons : con
# UI : ui
# buggy : buggy
# graphics : graph
# are : ar
# become : becom
# very : very
# annoying : annoy
# all : al
# sporadic : sporad
# glitches : glitch
# system : system
# On : on
# bright : bright
# side : sid
# something : someth
# could : could
# be : be
# completely : complet
# fixed : fix
# either : eith
# future : fut
# updates : upd
# installing : instal
# custom : custom
# ROM : rom
# Although : although
# may : may
# more : mor
# difficult : difficult
# install : instal
# device : dev
# its : it
# recent : rec
# launch : launch
# Develop : develop
# actually : act
# need : nee
# build : build
# viable : viabl
# recovery : recovery
# software : softw
# ROMs : rom
# compatible : compat
# particular : particul
# So : so
# fortunately : fortun
# as : as
# time : tim
# goes : goe
# likeliness : lik
# of : of
# becoming : becom
# really : real
# awsome : awsom
# budget : budget
# solution : solv
# will : wil
# greatly : gre
# increase : increas
# received : receiv
# yesterday : yesterday
# mobile : mobl
# charges : charg
# quickly : quick
# has : has
# power : pow
# day : day
# am : am
# satisfied : satisfy
# If : if
# live : liv
# US : us
# avoid : avoid
# at : at
# costs : cost
# radios : radio
# functional : funct
# You : you
# drop : drop
# every : every
# get : get
# miss : miss
# 80 : 80
# them : them
# Those : thos
# do : do
# talk : talk
# hear : hear
# what : what
# sounds : sound
# like : lik
# cafeteria : cafeter
# return : return
# wait : wait
# find : find
# else : els
# Just : just
# huge : hug
# pain : pain
# ve : ve
# been : been
# using : us
# daily : dai
# drive : driv
# experience : expery
# A : a
# awesome : awesom
# pleasant : pleas
# eyes : ey
# dark : dark
# mode : mod
# built : built
# Amazing : amaz
# never : nev
# having : hav
# worrying : worry
# about : about
# charging : charg
# often : oft
# which : which
# nice : nic
# As : as
# well : wel
# being : being
# use : us
# almost : almost
# any : any
# provider : provid
# MetroPCS : metropc
# T : t
# Mobile : mobl
# Really : real
# hoping : hop
# brings : bring
# phones : phon
# over : ov
# west : west
# This : thi
# bang : bang
# buck : buck
# highly : high
# needed : nee
# here : her
# Going : going
# sticking : stick
# brand : brand
# while : whil
# Good : good
# price : pric
# AT : at
# LTE : lte
# connection : connect
# problems : problem
# Angeles : angel
# area : are
# Corresponde : correspond
# las : las
# expectativas : expectativa
# much : much
# cell : cel
# read : read
# emails : email
# take : tak
# pictures : pict
# record : record
# videos : video
# vida : vid
# buena : buen
# Pero : pero
# celular : celul
# Se : se
# arruino : arruino
# menos : meno
# 2 : 2
# meses : mes
# work : work
# Me : me
# encanto : encanto
# tuve : tuv
# regresar : regres
# venia : ven
# deabloqueado : deabloqueado
# El : el
# mejor : mej
# tenido : tenido
# Excelente : excel
# relación : relación
# precio : precio
# calidad : calidad
# cuenta : cuent
# varias : varia
# funciones : funt
# gama : gam
# bajo : bajo
# costo : costo
# comparado : comparado
# otros : otro
# mercado : mercado
# Lamentablemente : lam
# operadores : operad
# Estados : estado
# Unidos : unido
# tube : tub
# producto : producto
# puedo : puedo
# usarlo : usarlo
# bandas : banda
# trae : tra
# europa : europ
# América : améric
# usamos : usamo
# europeas : europea
# posiblemente : pos
# puede : pued
# funcione : funt
# 2G : 2g
# sería : serí
# agradable : agrad
# hay : hay
# operadoras : operadora
# got : got
# lemon : lemon
# today : today
# Phone : phon
# reboot : reboot
# two : two
# three : three
# minutes : minut
# touch : touch
# frequently : frequ
# freeze : freez
# give : giv
# replacement : replac
# company : company
# thank : thank
# Will : wil
# update : upd
# i : i
# receive : receiv
# único : único
# gusta : gust
# siento : siento
# cuando : cuando
# respaldo : respaldo
# WhatsApp : whatsap
# tarda : tard
# muchoPor : muchop
# demás : demá
# bien : bien
# Esta : est
# correctamente : correcta
# Buen : buen
# equipo : equipo
# beneficio : beneficio
# thing : thing
# absolute : absolv
# favorite : favorit
# bought : bought
# because : becaus
# was : was
# long : long
# overdue : overdu
# an : an
# upgrade : upgrad
# My : my
# last : last
# already : already
# kind : kind
# old : old
# years : year
# ago : ago
# fantastic : fantast
# little : littl
# everything : everyth
# high : high
# end : end
# quarter : quart
# Between : between
# 4K : 4k
# 64Mp : 64mp
# t : t
# complain : complain
# had : had
# warn : warn
# anything : anyth
# slowmo : slowmo
# feature : feat
# Yes : ye
# only : on
# slows : slow
# down : down
# second : second
# video : video
# bad : bad
# math : math
# seconds : second
# phenomenal : phenom
# though : though
# incredibly : incred
# responsive : respond
# gorgeous : gorg
# back : back
# pretty : pretty
# decided : decid
# clear : clear
# hide : hid
# afraid : afraid
# going : going
# break : break
# know : know
# absolutely : absolv
# worth : wor
# than : than
# they : they
# asking : ask
# did : did
# 9 : 9
# those : thos
# thoughts : thought
# changed : chang
# Day : day
# 1 : 1
# arrived : ar
# lovely : lov
# piece : piec
# equipment : equip
# ordered : ord
# green : green
# size : siz
# weight : weight
# looked : look
# narrower : narrow
# shorter : short
# galaxy : galaxy
# note : not
# fit : fit
# into : into
# redmi : redm
# PROSScreen : prosscreen
# Side : sid
# fingerprint : fingerprint
# detection : detect
# button : button
# novel : novel
# games : gam
# play : play
# were : wer
# connected : connect
# wifi : wif
# overall : overal
# look : look
# pleasing : pleas
# CONSI : cons
# couldn : couldn
# incoming : incom
# calls : cal
# callers : cal
# didn : didn
# leave : leav
# voice : voic
# message : mess
# text : text
# would : would
# known : known
# called : cal
# Call : cal
# quality : qual
# poor : poor
# people : peopl
# barely : bar
# speaker : speak
# subpar : subp
# opinion : opin
# loud : loud
# also : also
# definitely : definit
# equalizer : eq
# literally : lit
# took : took
# 45 : 45
# line : lin
# ring : ring
# after : aft
# number : numb
# dialed : dial
# EVERY : every
# made : mad
# Honestly : honest
# if : if
# basic : bas
# function : funct
# making : mak
# receiving : receiv
# d : d
# consider : consid
# keeping : keep
# don : don
# lot : lot
# calling : cal
# expect : expect
# unlocked : unlock
# GSM : gsm
# expected : expect
# properly : prop
# carrier : carry
# deal : deal
# breaker : break
# love : lov
# shouldn : shouldn
# 250 : 250
# sooo : sooo
# even : ev
# gets : get
# praise : pra
# course : cours
# full : ful
# 64mp : 64mp
# stacks : stack
# images : im
# cleanest : cleanest
# ever : ev
# seen : seen
# under : und
# 500 : 500
# amazing : amaz
# out : out
# box : box
# lasted : last
# half : half
# reader : read
# picky : picky
# means : mean
# gonna : gonn
# let : let
# error : er
# around : around
# especially : espec
# gaming : gam
# whatever : whatev
# want : want
# latency : lat
# llego : llego
# novedad : novedad
# aunque : aunqu
# fue : fue
# importado : importado
# Ecuador : ecuad
# ningun : ningun
# daño : daño
# empaquetado : empaquetado
# tuvo : tuvo
# ningún : ningún
# owning : own
# paying : pay
# Samsung : samsung
# A70 : a70
# liked : lik
# finger : fing
# print : print
# scanner : scan
# crap : crap
# tried : tri
# through : through
# help : help
# told : told
# since : sint
# universal : univers
# wasn : wasn
# covered : cov
# Then : then
# broke : brok
# YAY : yay
# new : new
# reading : read
# up : up
# reviews : review
# comparing : comp
# specs : spec
# recommend : recommend
# 100 : 100
# speak : speak
# crystal : cryst
# runs : run
# Apps : ap
# perfectly : perfect
# Buy : buy
# hardware : hardw
# Snapdragon : snapdragon
# 720G : 720g
# 128GB : 128gb
# 6GB : 6gb
# 2400 : 2400
# x : x
# 1080 : 1080
# FHD : fhd
# 64MP : 64mp
# etc : etc
# Major : maj
# dump : dump
# equip : equip
# iPhone : iphon
# knock : knock
# Launcher : launch
# totally : tot
# lacks : lack
# affinity : affin
# Android : android
# Bloatware : bloatw
# make : mak
# worse : wors
# cannot : cannot
# without : without
# bloatware : bloatw
# their : their
# own : own
# launcher : launch
# stock : stock
# functionalities : funct
# ridiculous : ridic
# replace : replac
# inferior : infery
# home : hom
# brew : brew
# flexware : flexw
# wish : wish
# understand : understand
# buyers : buy
# Es : es
# excelente : excel
# inversion : invert
# tienes : tien
# 8 : 8
# pro : pro
# gusto : gusto
# camara : camar
# sobresale : sobres
# carcaza : carcaz
# ya : ya
# nota : not
# Funciona : funcion
# rapido : rapido
# toma : tom
# buenas : buena
# mucho : mucho
# gigante : gig
# Tardare : tard
# buen : buen
# tiempo : tiempo
# este : est
# LOVE : lov
# unfortunately : unfortun
# issues : issu
# breakers : break
# returning : return
# AMAZING : amaz
# Seriously : sery
# past : past
# keep : keep
# alone : alon
# crisp : crisp
# color : col
# notch : notch
# charge : charg
# moderate : mod
# phantom : phantom
# touches : touch
# sometimes : sometim
# haven : hav
# touched : touch
# hover : hov
# thinks : think
# tapped : tap
# supported : support
# by : by
# most : most
# carriers : carry
# Verizon : verizon
# Tmobile : tmobl
# accept : acceiv
# IMEI : ime
# guarantee : guar
# networks : network
# global : glob
# international : intern
# version : vert
# said : said
# based : bas
# SIM : sim
# iphone : iphon
# 7 : 7
# until : until
# gave : gav
# bars : bar
# coverage : cov
# Insert : insert
# immediately : immedy
# dropped : drop
# bar : bar
# service : serv
# intermittently : intermit
# lose : los
# thought : thought
# crummy : crummy
# activated : act
# instructions : instruct
# found : found
# online : onlin
# still : stil
# able : abl
# spent : spent
# HOURS : hour
# both : both
# tech : tech
# support : support
# won : won
# diminishing : dimin
# reception : receiv
# 75 : 75
# That : that
# IS : is
# Wish : wish
# model : model
# takes : tak
# hours : hour
# charged : charg
# whereas : wherea
# say : say
# should : should
# Also : also
# short : short
# fake : fak
# Swapping : swap
# existing : ex
# Metro : metro
# okay : okay
# Huge : hug
# warnings : warn
# package : pack
# type : typ
# right : right
# away : away
# opening : op
# whiners : whin
# moaning : moan
# warned : warn
# There : ther
# sim : sim
# slots : slot
# slot : slot
# closest : closest
# memory : mem
# card : card
# first : first
# nifty : nifty
# Display : display
# speed : spee
# Camera : camer
# seems : seem
# alright : alright
# mess : mess
# tired : tir
# slower : slow
# 4g : 4g
# ram : ram
# cpus : cpu
# 6g : 6g
# spry : spry
# 720 : 720
# checks : check
# boxes : box
# less : less
# One : on
# downer : down
# wireless : wireless
# womp : womp
# UPDATE : upd
# 11 : 11
# 21 : 21
# performance : perform
# looking : look
# point : point
# Fast : fast
# Shipping : ship
# shipped : ship
# Mine : min
# came : cam
# European : europ
# charger : charg
# USA : us
# spare : spar
# Other : oth
# beautiful : beauty
# big : big
# heavy : heavy
# Carrier : carry
# Wingalpha : wingalph
# com : com
# bit : bit
# worried : worry
# wouldn : wouldn
# But : but
# anxiety : anxy
# gone : gon
# once : ont
# set : set
# worked : work
# flawless : flawless
# Definitely : definit
# P : p
# pre : pre
# installed : instal
# protector : protect
# normally : norm
# noticed : not
# Update : upd
# months : month
# Still : stil
# From : from
# loyal : loy
# LG : lg
# customer : custom
# V30 : v30
# sound : sound
# started : start
# lacking : lack
# beats : beat
# spades : spad
# Battery : battery
# best : best
# part : part
# used : us
# straight : straight
# data : dat
# constantly : const
# before : bef
# recharging : recharg
# Never : nev
# 300 : 300
# always : alway
# buy : buy
# generations : gen
# behind : behind
# quirks : quirk
# And : and
# unfair : unfair
# compare : comp
# year : year
# Firstly : first
# Chinese : chines
# security : sec
# risk : risk
# Lately : lat
# from : from
# Venmo : venmo
# unauthorized : unauth
# sign : sign
# ins : in
# another : anoth
# breach : breach
# Secondly : second
# MIUI : miu
# android : android
# customizable : custom
# Flagship : flag
# Can : can
# control : control
# game : gam
# frame : fram
# rate : rat
# running : run
# moot : moot
# cool : cool
# apps : ap
# split : split
# bottom : bottom
# 50 : 50
# 66 : 66
# 33 : 33
# drag : drag
# float : flo
# corner : corn
# window : window
# change : chang
# aspect : aspect
# ratio : ratio
# resolution : resolv
# screenThirdly : screenthirdly
# sure : sur
# bands : band
# create : cre
# APN : apn
# send : send
# txts : txts
# mms : mms
# fully : ful
# outgoing : outgo
# January : janu
# 2021 : 2021
# subscribers : subscrib
# VoLTE : volt
# seem : seem
# 3G : 3g
# speeds : spee
# indicated : ind
# status : stat
# dig : dig
# settings : set
# see : see
# downstream : downstream
# Wifi : wif
# Fourthly : fourth
# Looked : look
# everywhere : everywh
# signal : sign
# Fifth : fif
# minor : min
# things : thing
# too : too
# tall : tal
# 20 : 20
# LCD : lcd
# OLED : ol
# Light : light
# bleed : blee
# thru : thru
# hand : hand
# brightness : bright
# prefer : pref
# better : bet
# blacks : black
# grays : gray
# light : light
# bleeding : blee
# Sixth : six
# transferring : transfer
# accounts : account
# seamless : seamless
# Every : every
# generation : gen
# allowed : allow
# transfer : transf
# restore : rest
# email : email
# follow : follow
# main : main
# stuck : stuck
# Google : googl
# account : account
# Had : had
# again : again
# unlike : unlik
# seamlessness : seamless
# process : process
# focused : focus
# negatives : neg
# positives : posit
# themselves : themselv
# For : for
# instance : inst
# rear : rear
# 64 : 64
# mp : mp
# 4k : 4k
# Conclusion : conclud
# holdover : holdov
# 5G : 5g
# Either : eith
# ll : ll
# go : go
# Edit : edit
# 12 : 12
# 16 : 16
# Forgot : forgot
# mention : ment
# waterproof : waterproof
# headphone : headphon
# jack : jack
# usually : us
# why : why
# review : review
# skews : skew
# isn : isn
# many : many
# features : feat
# readily : ready
# explained : explain
# other : oth
# repeating : rep
# nervous : nerv
# ordering : ord
# honestly : honest
# 1k : 1k
# researching : research
# affordable : afford
# alternatives : altern
# across : across
# decision : decid
# happy : happy
# head : head
# gives : giv
# run : run
# money : money
# alternative : altern
# Thank : thank
# Robin : robin
# Hood : hood
# premium : prem
# frugal : frug
# pleased : pleas
# wanted : want
# notifications : not
# decent : dec
# storage : stor
# weeks : week
# standards : standard
# bigger : big
# banned : ban
# hence : hent
# photos : photo
# browse : brows
# internet : internet
# lasts : last
# normal : norm
# usage : us
# Photos : photo
# People : peopl
# nicely : nic
# Seller : sel
# fast : fast
# within : within
# standard : standard
# shipping : ship
# Little : littl
# ur : ur
# palms : palm
# Initially : init
# Play : play
# store : stor
# however : howev
# factory : fact
# reset : reset
# With : with
# space : spac
# penny : penny
# simply : simply
# Galaxy : galaxy
# Many : many
# crazy : crazy
# plenty : plenty
# forever : forev
# must : must
# market : market
# below : below
# 800 : 800
# points : point
# insane : ins
# owned : own
# Even : ev
# Razer : raz
# impressed : impress
# excellent : excel
# boots : boot
# quick : quick
# flawlessbattery : flawlessbattery
# watching : watch
# netflix : netflix
# playing : play
# taking : tak
# pics : pic
# texting : text
# smsthe : smsthe
# ive : iv
# single : singl
# pic : pic
# 48 : 48
# MB : mb
# yes : ye
# 48MB : 48mb
# angles : angl
# adjustment : adjust
# flip : flip
# easily : easy
# x2 : x2
# x1 : x1
# magnification : magn
# fumbling : fumbl
# BUT : but
# adjust : adjust
# ALL : al
# camerassettings : camerasset
# BASE : bas
# cleaning : cle
# uninstall : uninstal
# theirs : their
# option : opt
# remove : remov
# IMO : imo
# llegó : llegó
# antes : ant
# acordado : acordado
# Bien : bien
# empacado : empacado
# tal : tal
# cual : cual
# descripción : descripción
# cellphone : cellphon
# sold : sold
# versión : versión
# indian : ind
# doesn : doesn
# 4G : 4g
# band : band
# REALLY : real
# FEEL : feel
# CHEATED : che
# sell : sel
# M2003J6B2G : m2003j6b2g
# Global : glob
# However : howev
# useless : useless
# Model : model
# M2003J6A1I : m2003j6a1i
# DEMAND : demand
# MY : my
# REFUND : refund
# wipe : wip
# date : dat
# asks : ask
# unlock : unlock
# previous : prevy
# password : password
# After : aft
# finally : fin
# downloaded : download
# iMyFone : imyfon
# LockWiper : lockwip
# computer : comput
# Eventually : ev
# asked : ask
# God : god
# hate : hat
# hassle : hassl
# Worth : wor
# samsung : samsung
# Apple : appl
# bucks : buck
# equipped : equip
# IPS : ip
# lcd : lcd
# equal : eq
# panels : panel
# needs : nee
# improvement : improv
# tooooooo : tooooooo
# loooooong : loooooong
# Lasts : last
# 3days : 3days
# Moderate : mod
# joke : jok
# cheap : cheap
# radio : radio
# important : import
# xiaomi : xiaom
# improved : improv
# vibration : vibr
# motor : mot
# haptic : hapt
# feedback : feedback
# removed : remov
# intensity : intens
# soft : soft
# medium : med
# hi : hi
# tapping : tap
# way : way
# strength : strength
# All : al
# default : default
# seriously : sery
# description : describ
# International : intern
# precise : prec
# exactly : exact
# About : about
# menu : menu
# says : say
# isVersion : isvert
# V11 : v11
# 0 : 0
# QJZEUXM : qjzeuxm
# MIUI11 : miui11
# According : accord
# makes : mak
# EEA : ee
# tablet : tablet
# large : larg
# capacity : capac
# batteries : battery
# processor : process
# comfortable : comfort
# unqualified : unqual
# USE : us
# network : network
# signals : sign
# weak : weak
# times : tim
# When : when
# intermittent : intermit
# automatically : autom
# interrupted : interrupt
# What : what
# value : valu
# punches : punch
# above : abov
# ways : way
# Great : gre
# cameras : camera
# smooth : smoo
# slightly : slight
# colors : col
# pop : pop
# true : tru
# flagship : flag
# By : by
# biggest : biggest
# frequent : frequ
# outages : out
# Sometimes : sometim
# disconnected : disconnect
# stop : stop
# working : work
# 30 : 30
# happens : hap
# fix : fix
# updated : upd
# miui : miu
# unlimited : unlimit
# beware : bew
# originally : origin
# 2018 : 2018
# uogradeable : uograd
# Blu : blu
# Pure : pur
# XL : xl
# Xioami : xioam
# Unfortunately : unfortun
# shattered : shat
# meant : meant
# went : went
# edition : edit
# available : avail
# sad : sad
# comparison : comparison
# gesture : gest
# relied : rely
# native : nat
# recording : record
# recordings : record
# conversation : convers
# apparently : app
# assume : assum
# lobbying : lobby
# campaign : campaign
# stifle : stifl
# competition : competit
# Further : furth
# evidence : evid
# indicate : ind
# users : us
# left : left
# srticlrs : srticlrs
# activates : act
# recorder : record
# catches : catch
# YOUR : yo
# faint : faint
# whisper : whisp
# caller : cal
# mouth : mou
# tries : tri
# heard : heard
# ear : ear
# same : sam
# failed : fail
# Xl : xl
# hails : hail
# Save : sav
# comparable : comp
# low : low
# American : am
# respects : respect
# save : sav
# trying : try
# enable : en
# absent : abs
# where : wher
# roundabout : roundabout
# check : check
# VoWifi : vowif
# enabled : en
# different : diff
# Calling : cal
# least : least
# U : u
# S : s
# staff : staff
# unable : un
# Jio : jio
# AirTel : airtel
# Considering : consid
# advertised : advert
# meet : meet
# expectations : expect
# hurt : hurt
# eye : ey
# longer : long
# whole : whol
# Moba : mob
# System : system
# Start : start
# Return : return
# Took : took
# Weeks : week
# To : to
# Get : get
# Part : part
# Of : of
# Money : money
# Back : back
# Around : around
# Short : short
# Original : origin
# Price : pric
# Give : giv
# Star : star
# Screen : screen
# Getting : get
# Bad : bad
# They : they
# Steal : ste
# Your : yo
# Terrible : terr
# Where : wher
# start : start
# rival : riv
# models : model
# including : includ
# although : although
# common : common
# series : sery
# stylus : styl
# name : nam
# misleading : mislead
# gigs : gig
# Octacore : octac
# 64mb : 64mb
# quad : quad
# lens : len
# shoots : shoot
# expandable : expand
# via : via
# MicroSD : microsd
# nearly : near
# bezel : bezel
# infinity : infin
# curved : curv
# bother : both
# despite : despit
# geek : geek
# ten : ten
# HUGE : hug
# 5000mAh : 5000mah
# wake : wak
# wring : wring
# neck : neck
# browsing : brows
# web : web
# YouTube : youtub
# movie : movy
# Prime : prim
# Netflix : netflix
# doing : doing
# constitutes : constitut
# glued : glu
# typically : typ
# remaining : remain
# Note8 : note8
# 3000mAh : 3000mah
# required : requir
# several : sev
# throughout : throughout
# impressive : impress
# extremely : extrem
# reboots : reboot
# noticeable : not
# lag : lag
# closing : clos
# tax : tax
# such : such
# HD : hd
# players : play
# multiple : multipl
# background : background
# aren : ar
# cons : con
# none : non
# espec : espec
# mentioning : ment
# somewhat : somewh
# bulky : bulky
# possible : poss
# spoiled : spoil
# glass : glass
# construction : construct
# later : lat
# bulk : bulk
# consistent : consist
# brands : brand
# relative : rel
# week : week
# bothered : both
# TL : tl
# DR : dr
# powerful : pow
# toe : toe
# 240 : 240
# doubtful : doubt
# destroys : destroy
# incredible : incred
# links : link
# open : op
# google : googl
# browser : brows
# amazon : amazon
# saying : say
# oops : oop
# wrong : wrong
# Upgrading : upgrad
# Mi : mi
# A1 : a1
# fan : fan
# debloated : deblo
# smoothly : smooth
# versatile : versatil
# stabilization : stabl
# 5x : 5x
# 6x : 6x
# wide : wid
# scenic : scen
# views : view
# macro : macro
# supports : support
# GCam : gcam
# lapse : laps
# photo : photo
# spheres : spheres
# gripe : grip
# easy : easy
# Lycamobile : lycamobl
# MVNO : mvno
# provide : provid
# initial : init
# impression : impress
# In : in
# summary : sum
# reasonable : reason
# elaborate : elab
# form : form
# opinionsFirst : opinionsfirst
# reflects : reflect
# differently : diff
# various : vary
# Both : both
# front : front
# gorilla : gorill
# durable : dur
# clean : cle
# neat : neat
# fault : fault
# rim : rim
# plastic : plast
# metal : met
# First : first
# notice : not
# cause : caus
# concern : concern
# appears : appear
# sturdy : sturdy
# obviously : obvy
# deep : deep
# contrast : contrast
# AMOLES : amol
# XR : xr
# matches : match
# Outdoor : outdo
# visibility : vis
# Software : softw
# Performance : perform
# installs : instal
# booting : boot
# we : we
# ideally : id
# Hopefully : hop
# soon : soon
# experienced : expery
# slowness : slow
# lags : lag
# installer : instal
# helpful : help
# drawer : draw
# dedicated : ded
# bump : bump
# snappy : snappy
# intensive : intend
# subway : subway
# surfers : surf
# asphalt : asphalt
# complained : complain
# heats : heat
# iPhones : iphon
# heating : heat
# concernCameras : concerncamera
# primary : prim
# MP : mp
# yet : yet
# try : try
# portrait : portrait
# regular : regul
# angle : angl
# night : night
# photography : photograph
# Especially : espec
# field : field
# view : view
# allows : allow
# snapped : snap
# picture : pict
# 40 : 40
# standing : stand
# group : group
# close : clos
# snap : snap
# gathering : gath
# bring : bring
# Happy : happy
# XS : xs
# Max : max
# getting : get
# capabilities : cap
# produces : produc
# blur : blur
# effect : effect
# reasonably : reason
# edge : edg
# Regarding : regard
# selfie : selfy
# seemed : seem
# ok : ok
# artificial : art
# preferred : prefer
# farConnectivity : farconnect
# flawlessly : flawless
# Upload : upload
# download : download
# WiFi : wif
# speedIt : speedit
# monster : monst
# 4500 : 4500
# mAmp : mamp
# damn : damn
# reached : reach
# done : don
# played : play
# watched : watch
# sent : sent
# messages : mess
# browsed : brows
# 18W : 18w
# North : nor
# 27W : 27w
# Essential : ess
# additions : addit
# possibly : poss
# IR : ir
# blaster : blast
# TVs : tvs
# micro : micro
# SD : sd
# expansion : expand
# intend : intend
# retrieval : retriev
# separately : sep
# arrives : ar
# lastly : last
# mm : mm
# Hardly : hard
# ms : ms
# shaping : shap
# nowPlease : nowpleas
# insights : insight
# upgraded : upgrad
# mid : mid
# level : level
# consideration : consid
# bunch : bunch
# searching : search
# combination : combin
# cost : cost
# research : research
# unit : unit
# month : mon
# user : us
# consumption : consum
# personal : person
# average : av
# Same : sam
# setup : setup
# shots : shot
# options : opt
# Bluetooth : bluetoo
# Headphone : headphon
# Jack : jack
# output : output
# interface : interfac
# feels : feel
# setting : set
# special : spec
# ignore : ign
# suggest : suggest
# anyone : anyon
# apple : appl
# nothing : noth
# modified : mod
# filled : fil
# prevents : prev
# centain : centain
# USB : usb
# installation : instal
# developer : develop
# then : then
# luck : luck
# register : reg
# GPS : gps
# location : loc
# sketchy : sketchy
# illegal : illeg
# manufacturer : manufact
# Anytime : anytim
# direct : direct
# log : log
# access : access
# hoops : hoop
# hiding : hid
# stay : stay
# 2019 : 2019
# OS : os
# black : black
# logs : log
# activity : act
# creating : cre
# steps : step
# worst : worst
# fail : fail
# OnePlus : onepl
# 5T : 5t
# 7T : 7t
# pixel : pixel
# Asus : as
# Zen : zen
# Everything : everyth
# legit : legit
# Got : got
# arrival : ar
# unscratched : unscratch
# Puerto : puerto
# Rico : rico
# wondering : wond
# Claro : claro
# Provided : provid
# utterly : ut
# forced : forc
# Witch : witch
# bummer : bum
# brick : brick
# care : car
# bricks : brick
# posted : post
# beast : beast
# believe : believ
# match : match
# against : against
# daughter : daught
# Came : cam
# beautifully : beauty
# packaged : pack
# ready : ready
# popped : pop
# fence : fent
# hesitate : hesit
# zero : zero
# stars : star
# excited : excit
# upon : upon
# malfunctioning : malfunct
# freezing : freez
# shutting : shut
# itself : itself
# corrupted : corrupt
# turning : turn
# annoyed : annoy
# garbage : garb
# these : thes
# usable : us
# warranty : warranty
# expiring : expir
# ZTE : zte
# ZMAX : zmax
# 2015 : 2015
# prior : pri
# fraction : fract
# discharged : discharg
# Honor : hon
# acting : act
# delays : delay
# knew : knew
# Remi : rem
# Thanks : thank
# frequency : frequ
# site : sit
# how : how
# Version : vert
# versions : vert
# wend : wend
# overpaid : overpaid
# prices : pric
# blame : blam
# coronavirus : coronavir
# lol : lol
# tell : tel
# regret : regret
# solid : solid
# Canon : canon
# Mark : mark
# II : ii
# Selfies : selfy
# lost : lost
# driving : driv
# Interstate : interst
# story : story
# office : off
# building : build
# Fingerprint : fingerprint
# charm : charm
# Face : fac
# recognition : recognit
# giving : giv
# between : between
# technical : techn
# world : world
# amazes : amaz
# gb : gb
# difference : diff
# extra : extr
# duration : dur
# 32 : 32
# gm : gm
# external : extern
# doubt : doubt
# forest : forest
# white : whit
# Included : includ
# silicone : silicon
# bonus : bon
# adapter : adapt
# ended : end
# buying : buy
# capability : cap
# thinking : think
# considering : consid
# newer : new
# announced : annount
# waste : wast
# Hoping : hop
# At : at
# Umidigi : umidig
# adequately : adequ
# returned : return
# overseas : oversea
# feel : feel
# dish : dish
# order : ord
# Maybe : mayb
# someone : someon
# lazy : lazy
# search : search
# hope : hop
# meanwhile : meanwhil
# cellphones : cellphon
# Nova : nov
# purchased : purchas
# eventually : ev
# revert : revert
# checking : check
# Right : right
# seemless : seemless
# TMobile : tmobl
# multimedia : multimed
# Haven : hav
# person : person
# scrolling : scrolling
# buttery : buttery
# lightning : lightn
# Cricket : cricket
# Wireless : wireless
# rural : rur
# Maryland : maryland
# truly : tru
# 220 : 220
# 750 : 750
# camper : camp
# finding : find
# exploring : expl
# expecting : expect
# happier : happy
# Feels : feel
# sleek : sleek
# hands : hand
# navigate : navig
# ton : ton
# bloat : blo
# ware : war
# 24 : 24
# moving : mov
# forward : forward
# DDR : ddr
# 6gb : 6gb
# newest : newest
# 8gb : 8gb
# blazing : blaz
# stick : stick
# xiachow : xiachow
# S4 : s4
# anticipated : anticip
# s21 : s21
# disappointment : disappoint
# downgrade : downgrad
# s20 : s20
# prepurchased : prepurchas
# realized : real
# Some : som
# include : includ
# Resolution : resolv
# QHD : qhd
# 3200 : 3200
# 1440 : 1440
# Ram : ram
# 12GB : 12gb
# GB3 : gb3
# gone4 : gone4
# Pressure : press
# testing : test
# CPU : cpu
# 888 : 888
# 865 : 865
# consumes : consum
# heated : heat
# Case : cas
# material : mat
# downgraded : downgrad
# plastic6 : plastic6
# Missing : miss
# headset : headset
# s21In : s21in
# significantly : sign
# wants : want
# cable : cabl
# ends : end
# connections : connect
# aux : aux
# Very : very
# disappointing : disappoint
# paid : paid
# 700 : 700
# 92 : 92
# drops : drop
# Surprise : surpr
# purchase : purchas
# Worked : work
# couls : coul
# powered : pow
# compared : comp
# Memory : mem
# Quite : quit
# Brand : brand
# upgrading : upgrad
# 2017 : 2017
# J7 : j7
# V : v
# Does : doe
# Loving : lov
# Again : again
# coming : com
# perks : perk
# purchasing : purchas
# skeptical : skept
# SUPER : sup
# mint : mint
# condition : condit
# Fully : ful
# UNLOCKED : unlock
# Network : network
# Recommendation : recommend
# 10Packaging : 10packaging
# 10Respect : 10respect
# Jamaica : jamaic
# Muy : muy
# bueno : bueno
# Euro : euro
# Nord : nord
# N10 : n10
# minded : mind
# SnapDragon : snapdragon
# 690 : 690
# capable : cap
# Adreno : adreno
# 619L : 619l
# GPU : gpu
# latest : latest
# laggy : laggy
# COD : cod
# Warzone : warzon
# Coming : com
# 2GB : 2gb
# flagships : flag
# 90Hz : 90hz
# refresh : refresh
# feeling : feel
# faster : fast
# Gorilla : gorill
# Glass : glass
# water : wat
# resistant : resist
# Pixel : pixel
# 4A : 4a
# Oxygen : oxyg
# optimization : optim
# Game : gam
# Fnatic : fnat
# cut : cut
# watch : watch
# movies : movy
# directs : direct
# resources : resourc
# choose : choos
# Includes : includ
# total : tot
# included : includ
# 3D : 3d
# Benchmarks : benchmark
# Slingshot : slingshot
# Extreme : extrem
# interested : interest
# raw : raw
# numbers : numb
# handling : handl
# tougher : tough
# applications : apply
# includes : includ
# Enjoy : enjoy
# complaints : complaint
# warp : warp
# shuts : shut
# twice : twic
# during : dur
# alarms : alarm
# morning : morn
# dual : dual
# tray : tray
# recommended : recommend
# ATT : at
# EE : ee
# Absolutely : absolv
# files : fil
# slight : slight
# inconvenience : inconveny
# Charger : charg
# pin : pin
# wobbly : wobbl
# Dual : dual
# smart : smart
# India : ind
# sims : sim
# travel : travel
# Sim : sim
# UK : uk
# Supplier : supply
# delivery : delivery
# stated : stat
# sim2 : sim2
# currently : cur
# patchy : patchy
# anyway : anyway
# mostly : most
# Sims : sim
# verizon : verizon
# THIS : thi
# AN : an
# BUDGET : budget
# PHONE : phon
# oneplus : onepl
# who : who
# higher : high
# accidentally : accid
# myself : myself
# ONLY : on
# seller : sel
# title : titl
# clearer : clear
# CDMA : cdma
# basing : bas
# rating : rat
# exact : exact
# besides : besid
# switched : switch
# NORD : nord
# plus : plu
# sd : sd
# Manufactures : manufact
# hybrid : hybrid
# blurry : blurry
# Havent : hav
# till : til
# hors : hor
# Its : it
# plan : plan
# Needed : nee
# swipe : swip
# nor : nor
# sprint : sprint
# tine : tin
# benefic : benef
# Pesimo : pesimo
# mes : mes
# compre : compr
# comenzo : comenzo
# escucharse : escuchars
# audicion : aud
# llamas : llama
# costumer : costum
# reemplazo : reemplazo
# devolucion : devoluc
# te : te
# dicen : dic
# areglarlo : areglarlo
# mas : mas
# opcion : opc
# caro : caro
# cuesta : cuest
# verdad : verdad
# pa : pa
# comprar : compr
# 31 : 31
# IF : if
# YOU : you
# DIDN : didn
# RECEIVE : receiv
# WIRED : wir
# AKG : akg
# headphones : headphon
# add : ad
# customers : custom
# 726 : 726
# 7864 : 7864
# request : request
# yours : yo
# free : fre
# mine : min
# scammed : scam
# wired : wir
# grain : grain
# salt : salt
# rendered : rend
# fairly : fair
# expensive : expend
# S20 : s20
# Ultra : ultr
# obsolete : obsolet
# units : unit
# pros : pro
# IPhone : iphon
# max : max
# 4XL : 4xl
# bests : best
# wider : wid
# ultra : ultr
# example : exampl
# outstanding : outstand
# perfect : perfect
# conditions : condit
# dunno : dunno
# cropping : crop
# yield : yield
# result : result
# modes : mod
# pen : pen
# useful : us
# notes : not
# except : exceiv
# eventhough : eventhough
# selling : sel
# Yup : yup
# design : design
# wise : wis
# putting : put
# covers : cov
# personally : person
# slim : slim
# transparent : transp
# added : ad
# gimmicky : gimmicky
# loved : lov
# share : shar
# show : show
# cast : cast
# TV : tv
# chrome : chrome
# attached : attach
# certain : certain
# mentioned : ment
# anywhere : anywh
# outdoor : outdo
# next : next
# instead : instead
# surprise : surpr
# smaller : smal
# practical : pract
# Now : now
# guess : guess
# preface : prefac
# supporting : support
# devices : dev
# near : near
# desired : desir
# soooooo : soooooo
# slow : slow
# searches : search
# load : load
# Hotspot : hotspot
# downright : downright
# awful : aw
# sub : sub
# Leica : leic
# figured : fig
# scam : scam
# earbuds : earbud
# clone : clon
# connector : connect
# Don : don
# spectacular : spectacul
# 120hz : 120hz
# maybe : mayb
# sec : sec
# worthless : worthless
# Scrolling : scrolling
# page : pag
# posts : post
# information : inform
# diagnosed : diagnos
# He : he
# tested : test
# his : his
# test : test
# additional : addit
# 15 : 15
# connect : connect
# starting : start
# advice : adv
# markets : market
# mean : mean
# falls : fal
# Mate : mat
# compete : compet
# hater : hat
# solidifies : solid
# viewpoint : viewpoint
# Won : won
# mistake : mistak
# defense : defens
# isolated : isol
# incident : incid
# simple : simpl
# Best : best
# Busy : busy
# Slow : slow
# city : city
# happen : hap
# period : period
# consumers : consum
# swapping : swap
# girlfriend : girlfriend
# directly : direct
# voicemail : voicemail
# hit : hit
# idea : ide
# hourly : hour
# employees : employ
# realm : realm
# troubleshoot : troubleshoot
# switch : switch
# min : min
# couple : coupl
# delayed : delay
# response : respons
# SMH : smh
# confused : confus
# whether : wheth
# ie : ie
# toggle : toggl
# buddy : buddy
# mind : mind
# boggling : boggl
# self : self
# employed : employ
# lifeline : lifelin
# release : releas
# Such : such
# shame : sham
# history : hist
# HTML5 : html5
# defect : defect
# registering : reg
# circular : circul
# failure : fail
# 1500 : 1500
# IMPORTANT : import
# EDIT : edit
# Noticed : not
# occurring : occur
# phenomenon : phenomenon
# caused : caus
# Steelie : ste
# magnetic : magnet
# mount : mount
# encounter : encount
# score : scor
# reflect : reflect
# Purchased : purchas
# damaged : dam
# Deceptively : deceiv
# protectors : protect
# Pay : pay
# attention : at
# stopped : stop
# Hz : hz
# probably : prob
# crown : crown
# key : key
# bumps : bump
# namely : nam
# planning : plan
# spend : spend
# Spigen : spig
# effectively : effect
# reduces : reduc
# allow : allow
# sit : sit
# flat : flat
# desk : desk
# IP68 : ip68
# dust : dust
# protection : protect
# saw : saw
# stat : stat
# recently : rec
# report : report
# incurring : incur
# damage : dam
# specifically : spec
# interesting : interest
# middle : middl
# class : class
# afford : afford
# pocket : pocket
# everyday : everyday
# cars : car
# houses : hous
# clothes : cloth
# swing : swing
# Lastly : last
# offer : off
# exceed : excess
# products : produc
# guy : guy
# specific : spec
# somebody : somebody
# machine : machin
# computing : comput
# Whites : whit
# dull : dul
# rez : rez
# impresionante : impres
# otro : otro
# habia : hab
# unas : una
# espectaculares : espectacul
# ademas : adema
# trabajo : trabajo
# lapiz : lap
# van : van
# genial : gen
# encantado : encantado
# opened : op
# small : smal
# scratches : scratches
# body : body
# previously : prevy
# soled : sol
# reshipped : reship
# Received : receiv
# false : fals
# advertisement : advert
# 4gb : 4gb
# upset : upset
# ripped : rip
# buyer : buy
# Box : box
# sealed : seal
# stickers : stick
# spec : spec
# suspicious : suspicy
# Customer : custom
# BREED : bree
# utter : ut
# garbageWill : garbagewil
# THEY : they
# CHANGED : chang
# IT : it
# TO : to
# NOT : not
# SHOW : show
# CHARGE : charg
# SAME : sam
# PRICE : pric
# FOR : for
# 4GB : 4gb
# wife : wif
# S8 : s8
# asap : asap
# A20s : a20s
# son : son
# A30s : a30s
# regarding : regard
# cancelled : cancel
# A51 : a51
# primarily : prim
# uses : us
# following : follow
# bands2 : bands2
# 71The : 71the
# list : list
# gladly : glad
# willing : wil
# ensure : ens
# maximum : maxim
# connectivity : connect
# parts : part
# connectivityThe : connectivityth
# s10 : s10
# microphone : microphon
# loves : lov
# speakerphone : speakerphon
# her : her
# s8 : s8
# occasionally : occas
# mic : mic
# pick : pick
# further : furth
# helps : help
# Reception : receiv
# We : we
# measured : meas
# signel : signel
# asu : asu
# areas : area
# weaker : weak
# ScreenSamsung : screensamsung
# AMOLEDs : amol
# business : busy
# relieved : reliev
# us : us
# robust : robust
# protect : protect
# indistuingishable : indistu
# tiny : tiny
# pinhole : pinhol
# entire : entir
# optical : opt
# rather : rath
# infrasonic : infrason
# talking : talk
# milliseconds : millisecond
# General : gen
# usabilityMy : usabilitymy
# gamer : gam
# she : she
# productivity : produc
# transition : transit
# multitasks : multitask
# shred : shred
# concerned : concern
# processing : process
# Switch : switch
# transfered : transf
# Once : ont
# rebooted : reboot
# CameraThe : camerath
# beefy : beefy
# shooter : shoot
# hard : hard
# setups : setup
# Picture : pict
# transitioning : transit
# instant : inst
# shutter : shut
# luckily : lucky
# BatteryI : battery
# admit : admit
# 4000mah : 4000mah
# 3500mah : 3500mah
# typical : typ
# percentage : perc
# scattered : scat
# busy : busy
# Mint : mint
# configuring : config
# researched : research
# website : websit
# ask : ask
# question : quest
# Spanish : span
# chose : chos
# English : engl
# Auto : auto
# preinstalled : preinstal
# Uninstalling : uninstal
# reinstalling : reinstal
# bugs : bug
# lower : low
# blue : blu
# cricket : cricket
# Pennsylvania : pennsylvan
# learning : learn
# differences : diff
# SM : sm
# A515F : a515f
# DS : ds
# internal : intern
# DSN : dsn
# Prism : prism
# Crush : crush
# Black : black
# April : april
# 2020 : 2020
# doorstep : doorstep
# accessories : access
# configuration : config
# beginning : begin
# Settings : set
# Mode : mod
# Natural : nat
# Vivid : vivid
# Dark : dark
# Biometrics : biomet
# Security : sec
# Fingerprints : fingerprint
# move : mov
# reads : read
# lines : lin
# fingers : fing
# login : login
# DID : did
# dogs : dog
# nose : nos
# WOW : wow
# stunning : stun
# lizard : lizard
# taken : tak
# Calls : cal
# strong : strong
# registered : reg
# dad : dad
# pass : pass
# Aside : asid
# Feitenn : feiten
# Metal : met
# ASIN : asin
# B0839C38GM : b0839c38gm
# DOES : doe
# together : togeth
# placed : plac
# Tempered : temp
# B082S7NCB8 : b082s7ncb8
# gig : gig
# might : might
# wont : wont
# iemi : iem
# likely : lik
# dont : dont
# att : at
# couldnt : couldnt
# a50 : a50
# early : ear
# censor : cens
# Motorola : motorol
# lg : lg
# fits : fit
# bells : bel
# whistles : whistl
# writing : writ
# rainbow : rainbow
# reflection : reflect
# Another : anoth
# responsiveness : respond
# handles : handl
# throw : throw
# id : id
# chance : chant
# S9 : s9
# perform : perform
# surpasses : surpass
# shot : shot
# eliminating : elimin
# winner : win
# continue : continu
# These : thes
# unbeatable : unb
# processors : process
# Saludos : saludo
# compré : compré
# metí : metí
# car : car
# PCS : pcs
# refleja : reflej
# realizar : realiz
# llamadas : llamada
# reseña : reseñ
# dice : dic
# debloqueado : debloqueado
# fábrica : fábrica
# obnoxious : obnoxy
# boot : boot
# loader : load
# cache : cach
# partition : partit
# starts : start
# reinstall : reinstal
# dialer : dial
# asian : as
# characters : charact
# Replaced : replac
# contacts : contact
# Text : text
# messaging : mess
# constant : const
# nag : nag
# screens : screens
# cloud : cloud
# Fixed : fix
# replacing : replac
# kept : kept
# popups : popup
# activate : act
# disabling : dis
# awkward : awkward
# minute : minut
# instantaneous : inst
# Excellent : excel
# Runs : run
# others : oth
# wash : wash
# Neither : neith
# positive : posit
# Probably : prob
# root : root
# miserable : mis
# felt : felt
# voLTE : volt
# alphabetize : alphabet
# closes : clos
# layer : lay
# suits : suit
# económico : económico
# rápido : rápido
# resistente : resist
# MTK : mtk
# Helio : helio
# G85 : g85
# alto : alto
# rendimiento : rendimiento
# octa : oct
# core : cor
# alta : alt
# capacidad : capacidad
# G : g
# Wi : wi
# Fi : fi
# publicidad : publicidad
# falsa : fals
# ese : es
# 64GB : 64gb
# vamos : vamo
# ver : ver
# recompensar : recompens
# tener : ten
# demandar : demand
# falcedad : falcedad
# Yo : yo
# pedi : ped
# desde : desd
# Republica : republic
# Dominicana : dominican
# bastante : bast
# devolverlo : devolverlo
# Le : le
# estrella : estrell
# darle : darl
# cero : cero
# Lots : lot
# choice : cho
# cases : cas
# Easy : easy
# 35 : 35
# recharge : recharg
# prints : print
# Mavic : mav
# Mini : min
# DJI : dji
# drone : dron
# outside : outsid
# 128gb : 128gb
# Sound : sound
# oldest : oldest
# DSLR : dslr
# Over : ov
# house : hous
# exceptional : exceiv
# bargain : bargain
# widely : wid
# notify : not
# viber : vib
# ebay : ebay
# trade : trad
# stocks : stock
# realize : real
# messed : mess
# sales : sal
# ads : ad
# spyware : spyw
# yourself : yourself
# Cameras : camera
# mediocre : mediocr
# 2xl : 2xl
# settled : settl
# Plenty : plenty
# 256mb : 256mb
# vivid : vivid
# detail : detail
# Night : night
# magnets : magnet
# seal : seal
# operating : op
# roughly : rough
# driver : driv
# trouble : troubl
# swap : swap
# aging : ag
# honor : hon
# 7X : 7x
# p : p
# 57 : 57
# HIDDEN : hid
# SETTINGS : set
# Ads : ad
# appear : appear
# MI : mi
# APPS : ap
# Cellular : cellul
# gigahertz : gigahertz
# router : rout
# 340 : 340
# megabytes : megabyt
# capping : cap
# border : bord
# glad : glad
# OTG : otg
# inn : in
# Hope : hop
# Too : too
# somehow : somehow
# relatively : rel
# offers : off
# Their : their
# convinced : convint
# sensors : sens
# ambient : amby
# outright : outright
# given : giv
# privacy : priv
# amount : amount
# programs : program
# kindly : kind
# benefit : benefit
# agreement : agr
# Do : do
# gallery : gallery
# agree : agr
# soul : soul
# book : book
# music : mus
# player : play
# file : fil
# explorer : expl
# chances : chant
# family : famy
# folder : fold
# random : random
# advertisements : advert
# Doing : doing
# aware : aw
# stealing : ste
# offloading : offload
# servers : serv
# abroad : abroad
# offender : offend
# meaning : mean
# sat : sat
# agreements : agr
# Cleaner : cle
# Why : why
# application : apply
# supposed : suppos
# cached : cach
# empty : empty
# trash : trash
# bin : bin
# identifiers : ident
# AND : and
# MESSAGES : mess
# countries : country
# proven : prov
# steal : ste
# age : ag
# plans : plan
# profit : profit
# trust : trust
# similar : simil
# companies : company
# 1000 : 1000
# dollars : doll
# performed : perform
# blown : blown
# vs : vs
# gotten : got
# friend : friend
# him : him
# ability : abl
# friendly : friend
# endless : endless
# themes : them
# Only : on
# downside : downsid
# lightly : light
# distance : dist
# wallet : wallet
# cracks : crack
# towards : toward
# bothers : both
# careful : car
# otherwise : otherw
# Quality : qual
# Levels : level
# Moto : moto
# displays : display
# Love : lov
# skin : skin
# Takes : tak
# learn : learn
# customization : custom
# rid : rid
# recommendations : recommend
# Control : control
# center : cent
# swipes : swip
# Florida : florid
# Red : red
# Pocket : pocket
# GSMA : gsma
# towers : tow
# Volte : volt
# mapping : map
# 17 : 17
# Most : most
# states : stat
# 17even : 17even
# listing : list
# v : v
# town : town
# stronger : stronger
# slipping : slip
# configured : config
# correctly : correct
# Unlocked : unlock
# isnt : isnt
# dosen : dos
# Argentina : argentin
# Please : pleas
# Movistar : movist
# Tuenti : tuent
# please : pleas
# questions : quest
# experts : expert
# Beautiful : beauty
# compra : compr
# articulo : articulo
# sonido : sonido
# cámara : cámara
# perfectas : perfecta
# condiciones : cond
# duda : dud
# algúna : algún
# volvería : volverí
# esperado : esperado
# vidrio : vidrio
# templado : templado
# gr8 : gr8
# Elegant : eleg
# Pokemon : pokemon
# Go : go
# superb : superb
# Top : top
# Gun : gun
# Trailer : trail
# Super : sup
# Poco : poco
# X3 : x3
# funny : funny
# cartoonish : cartoon
# image : im
# animation : anim
# eBay : ebay
# Make : mak
# Store : stor
# Services : serv
# rely : rely
# China : chin
# makers : mak
# releasing : releas
# local : loc
# classmate : classm
# Johnny : johnny
# fight : fight
# Peter : pet
# messy : messy
# each : each
# becomes : becom
# Simplesmente : simples
# fantástico : fantástico
# Este : est
# foi : foi
# meu : meu
# primeiro : primeiro
# da : da
# eu : eu
# estou : estou
# sem : sem
# palavras : palavra
# descrever : descrev
# quão : quão
# incrível : incrível
# tem : tem
# sido : sido
# experiência : experiênc
# O : o
# aparelho : aparelho
# é : é
# dúvida : dúvida
# muito : muito
# bom : bom
# E : e
# entrega : entreg
# chegou : chegou
# prazo : prazo
# Produto : produto
# ótima : ótim
# qualidade : qualidad
# não : não
# arrependo : arrependo
# ter : ter
# comprado : comprado
# recomendo : recomendo
# Loja : loj
# tbm : tbm
# boa : boa
# Chegou : chegou
# em : em
# dias : dia
# Perfeito : perfeito
# Celular : celul
# veio : veio
# queimado : queimado
# vendedor : vend
# quer : quer
# trocar : troc
# Péssimo : péssimo
# atendimento : atendimento
# nem : nem
# entrou : entrou
# contato : contato
# comigo : comigo
# apenas : apena
# mandou : mandou
# mail : mail
# incrivel : incrivel
# você : você
# quiser : quis
# ele : el
# canal : can
# falanerd : falanerd
# Parabéns : parabén
# só : só
# pelo : pelo
# final : fin
# semana : seman
# na : na
# quinta : quint
# recebi : receb
# segunda : segund
# feira : feir
# sábado : sábado
# já : já
# estava : estav
# correios : correio
# minha : minh
# cidade : cidad
# são : são
# Paulo : paulo
# Pirapora : pirapor
# mg : mg
# Valeu : valeu
# amigos : amigo
# mais : mai
# um : um
# cliente : cli
# satisfeito : satisfeito
# vou : vou
# divulgar : divulg
# link : link
# indicar : indic
# certeza : certez
# Panamá : panamá
# datos : dato
# maravilla : maravill
# Speakers : speak
# improve : improv
# Plus : plu
# 5Edit : 5edit
# Almost : almost
# SOMETIMES : sometim
# delay : delay
# exit : exit
# widgets : widget
# resolved : resolv
# team : team
# Symmetrical : symmet
# bezels : bezel
# punch : punch
# Using : us
# Fastest : fastest
# easiest : easiest
# Doesn : doesn
# Bueno : bueno
# Ese : es
# cuanto : cuanto
# diseño : diseño
# tons : ton
# current : cur
# range : rang
# hardly : hard
# Plays : play
# BYOD : byod
# failing : fail
# 71 : 71
# Better : bet
# A71 : a71
# gestures : gest
# Gpay : gpay
# Vibration : vibr
# thin : thin
# ID : id
# recognize : recogn
# Toma : tom
# increíbles : increíbl
# profundidad : profundidad
# IA : ia
# trabaja : trabaj
# elección : elección
# los : los
# colores : col
# velocidad : velocidad
# muchas : mucha
# opciones : opc
# personalización : personalización
# fuerte : fuert
# vaya : vay
# sabe : sab
# destacarse : destacars
# sus : sus
# atributos : atributo
# suave : suav
# gráfica : gráfica
# ligero : ligero
# Estoy : estoy
# opción : opción
